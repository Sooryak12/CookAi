# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("df-en-final.csv")

# %%
count={}

# %%
for i in range(len(df)):
    for i in df.loc[i,"P-Ingredients"].split(","):
        if i in count.keys():
            count[str(i)]+=1
        else:
            count[str(i)]=1

# %%
count
# Out:
# {'karela (bitter gourd pavakkai)': 31,
#  'salt': 5426,
#  'onion': 2345,
#  'gram flour (besan)': 320,
#  'turmeric powder (haldi)': 1917,
#  'red chilli powder': 1696,
#  'cumin seeds (jeera)': 1310,
#  'coriander powder (dhania)': 733,
#  'amchur (dry mango powder)': 204,
#  'sunflower oil': 2273,
#  'rice': 242,
#  'tomato': 1347,
#  'bc belle bhat powder': 1,
#  'chickpea lentils': 3,
#  'cumin seeds': 125,
#  'white urad dal': 79,
#  'mustard': 84,
#  'green chilli': 649,
#  'dry red chilli': 289,
#  'cashew peanuts': 1,
#  'oilasafoetida': 1,
#  'rice vermicelli noodles (thin)': 9,
#  'carrots (gajjar)': 177,
#  'green peas (matar)': 225,
#  'green chillies': 1299,
#  'asafoetida (hing)': 855,
#  'mustard seeds': 1077,
#  'white urad dal (split)': 367,
#  'ghee': 865,
#  'sprig curry leaves': 788,
#  'lemon juice': 791,
#  'chicken': 99,
#  'ginger': 1423,
#  'cloves garlic': 1561,
#  'garam masala powder': 809,
#  'sesame (gingelly) oil': 161,
#  'methi seeds (fenugreek seeds)': 279,
#  'coriander (dhania) seeds': 305,
#  'dry red chillies': 656,
#  'fennel seeds (saunf)': 323,
#  'sorrel leaves (gongura)': 2,
#  'chana dal': 21,
#  'red chillies': 35,
#  'coriander seeds': 25,
#  'asafoetida': 75,
#  'oil': 207,
#  'sprig curry': 1,
#  'yellow moong dal (split)': 121,
#  'mint leaves (pudina)': 278,
#  'coriander (dhania) leaves': 819,
#  'water': 1140,
#  'cashew nuts': 305,
#  'black peppercorns': 451,
#  'vellai poosanikai (ash gourdwhite pumpkin)': 10,
#  'coconut': 778,
#  'tamarind water': 129,
#  'sesame seeds (til seeds)': 203,
#  'jaggery': 411,
#  'tortillas': 28,
#  'black beans': 8,
#  'spinach leaves (palak)': 114,
#  'sprig coriander (dhania) leaves': 449,
#  'rice brown rice': 2,
#  'spring onion greens': 94,
#  'cheddar cheese': 64,
#  'hung curd (greek yogurt)': 146,
#  'idli': 5,
#  'green bell pepper (capsicum)': 289,
#  'tomato ketchup': 68,
#  'cabbage leaves': 1,
#  'tamarind': 96,
#  'turmeric powder': 204,
#  'spoon oil': 1,
#  'rye': 35,
#  'dry beans (such cannellini soya beans)': 2,
#  'virgin olive oil': 715,
#  'clove garlic': 58,
#  'hy': 286,
#  'cumin powder (jeera)': 654,
#  'dried oregano': 223,
#  'red chilli powder cayenne pepper': 3,
#  'pepper ( pepper)': 1,
#  'burger buns': 10,
#  'jalapenos': 42,
#  'cheese': 126,
#  'potatoes (aloo) pressure': 1,
#  'egg': 166,
#  'wheat bread crumbs': 101,
#  'soy granules': 8,
#  'red chilli flakes': 280,
#  'tabasco original sauce': 34,
#  'arhar dal (split toor dal)': 160,
#  'aar maach (fish) rohu katla fish (cut steaks)': 1,
#  'bay leaves (tej patta)': 108,
#  'ginger paste': 77,
#  'mustard oil': 242,
#  'sugar': 1067,
#  'potatoes (aloo) skin': 10,
#  'milk': 614,
#  'black urad dal (split)': 51,
#  'tamarind paste': 115,
#  'eggs': 314,
#  'cinnamon stick (dalchini)': 509,
#  'bay leaf (tej patta)': 317,
#  'cloves (laung)': 428,
#  'curd': 569,
#  'gourd': 5,
#  'cucumber grind': 1,
#  'green': 2,
#  'green coriander': 42,
#  'cumin powder': 49,
#  'potatoes (aloo)': 290,
#  'garlic powder': 36,
#  'onion powder': 11,
#  'flour (maida)': 508,
#  'rice flour': 185,
#  'sunflower oil the r tots': 1,
#  'bay leaf break': 4,
#  'carrot': 14,
#  'green beans': 15,
#  'potatoes': 21,
#  'cloves': 3,
#  'cinnamon': 34,
#  'fennel': 9,
#  'pepper': 229,
#  'green peas': 20,
#  'mint leaves': 6,
#  'amla': 4,
#  'bud garlic': 10,
#  'mint': 7,
#  'coriander': 32,
#  'urad dal': 3,
#  'wheat flour': 462,
#  'cucumber': 114,
#  'ghee on thalipeeth': 1,
#  'submarine bread (subway bread) (flat breads foot s)': 1,
#  'green moong sprouts': 49,
#  'beetroot': 72,
#  'stalks spring onion (bulb greens)': 15,
#  'drumstick': 37,
#  'coconut oil': 168,
#  'mango pulp (puree)': 17,
#  'saffron strands': 167,
#  'badam (almond)': 206,
#  'milk luke cold milk': 1,
#  'ice cubes': 40,
#  'idli dosa mixture': 2,
#  'rice rava': 6,
#  'cardamom powder': 8,
#  'cardamom (elaichi) podsseeds': 426,
#  'cloves cloves (laung)': 13,
#  'mace (javitri)': 40,
#  'black cardamom (badi elaichi)': 102,
#  'kasuri methi (dried fenugreek leaves)': 132,
#  'kashmiri red chilli powder': 168,
#  'samosas mini': 1,
#  'baguette': 10,
#  'butter': 644,
#  'garlic': 267,
#  'red bell pepper (capsicum) (': 1,
#  'black pepper powder': 801,
#  'italian': 39,
#  'tomato pasta sauce': 24,
#  'ajwain (carom seeds)': 233,
#  'chana dal (bengal gram dal)': 282,
#  'sweet chutney (date tamarind)': 40,
#  'green chutney (coriander mint)': 50,
#  'pomegranate fruit kernels': 35,
#  'sev': 25,
#  'green beans (french beans)': 145,
#  'soy sauce': 208,
#  'thai sweet chilli sauce': 2,
#  'rice wine vinegar': 12,
#  'peanuts (moongphali)': 215,
#  'baking powder': 271,
#  'water make the dough': 2,
#  'sesame seeds (til seeds) white': 7,
#  'vanilla': 289,
#  'sundkai': 1,
#  'fenugreek': 5,
#  'arhar dal': 10,
#  'sambar powder': 93,
#  'coriander powder': 106,
#  'curry leaves': 373,
#  'cabbage (patta gobi muttaikose)': 109,
#  'spinach': 110,
#  'green chilli sauce': 25,
#  'cinnamon powder (dalchini)': 188,
#  'dark chocolate': 45,
#  'cocoa powder': 95,
#  'salted butter': 14,
#  'baking soda': 160,
#  'britannia': 48,
#  'caster sugar': 161,
#  'raspberries': 2,
#  'ada': 1,
#  'milk full': 10,
#  'cardamom powder (elaichi)': 307,
#  'tindora (dondakaya kovakkai)': 9,
#  'split methi seeds (methi kuria)': 3,
#  'split mustard seeds (rai kuria)': 4,
#  'chicken legs': 7,
#  'kalonji (onion nigella seeds)': 68,
#  'jackfruit seeds (kathal)': 8,
#  'coriander (dhania)': 141,
#  'eggplant': 10,
#  'sprigs coriander': 7,
#  'tea leaves': 4,
#  'mango': 10,
#  'kala chana (brown chickpeas)': 49,
#  'cheese flavoured': 1,
#  'broccoli': 84,
#  'red bell pepper (capsicum)': 206,
#  'sprig parsley leaves': 36,
#  'makki ka atta (yellow corn meal flour)': 24,
#  'methi leaves (fenugreek leaves)': 94,
#  'dry yeast': 95,
#  'brown rice': 26,
#  'oregano': 4,
#  'rosemary': 43,
#  'ridge gourd skin (turai peerkangai)': 2,
#  'wheat (dalia godumai rava)': 25,
#  'water make pakora batter': 2,
#  'enos fruit salt': 42,
#  'sunflower oil the pakoras': 2,
#  'paneer': 219,
#  'chaat masala powder': 214,
#  'coal giving smoked flavour': 3,
#  'jasmine rice': 3,
#  'sweet corn': 145,
#  'parsley leaves': 81,
#  'parmesan cheese': 88,
#  'mozzarella cheese': 120,
#  'eggs fork': 2,
#  'fish fillet basa': 1,
#  'prawns': 30,
#  'clamps': 1,
#  'baby potatoes': 40,
#  'paprika powder': 91,
#  'chicken stock': 11,
#  'coconut milk': 197,
#  'hakka noodles': 15,
#  'red chilli sauce': 115,
#  'white vinegar': 20,
#  'dry red chillies (chilli flakes)': 1,
#  'potato (aloo)': 166,
#  'panch phoran masala': 42,
#  'broccoli florets': 26,
#  'nutralite cheesy garlic mayo': 10,
#  'corn flour': 196,
#  'nutralite garlic oregano pan roasting': 1,
#  'mooli mullangi (radish)': 44,
#  'kasundi mustard sauce': 7,
#  'chakundar': 3,
#  'sesame oil': 13,
#  'sprig coriander': 13,
#  'ku (parangikai pumpkin) (red preferably)': 1,
#  'water dough': 2,
#  'sunflower oil rotis': 1,
#  'poppy seeds': 128,
#  'bless chicken': 34,
#  'sweet spicy red chilli sauce (tomato chilli sauce)': 24,
#  'spring onion (bulb greens)': 71,
#  'chinese spice powder': 10,
#  'white pepper powder': 25,
#  'egg noodles tossed oil': 1,
#  'classic mayonnaise (with egg)': 26,
#  'vinegar': 94,
#  'bay leaf': 27,
#  'lentil sugar': 13,
#  'ginger garlic paste': 314,
#  'tomato take': 1,
#  'capsicum (green) red yellow': 1,
#  'tofu': 62,
#  'pav bhaji masala': 21,
#  'french bread rye bread': 1,
#  'rocket leaves salad leaves the sandwich': 1,
#  'red wine vinaigrette': 20,
#  'dijon mustard': 22,
#  'cane sugar': 4,
#  'mooli mullangi (radish) purple': 1,
#  'vivatta maida': 50,
#  'cashews': 30,
#  'green zucchini': 65,
#  'dried thyme leaves': 56,
#  'black pepper corns': 52,
#  'basil leaves': 102,
#  'peanuts (moongphali) fistful': 1,
#  'hog plum (amtekai) (ambade)': 1,
#  'rice (raw rice)': 4,
#  'cauliflower (gobi)': 80,
#  'black pepper powder red chilli powder': 1,
#  'anardana powder (pomegranate seed powder)': 38,
#  'pomegranate molasses orhy': 1,
#  'herbs herbs choice like basil': 1,
#  'milk powder': 31,
#  'vivatta maida bread flour': 1,
#  'egg white brushing (or milk': 1,
#  'basmati rice': 103,
#  'yellow bell pepper (capsicum)': 78,
#  'sesame seeds (til seeds) mixed black white': 1,
#  'poha (flattened rice)': 46,
#  'nolen gur brown sugar': 1,
#  'mixed nuts almondscashews': 1,
#  'raisins': 159,
#  'bok choy': 9,
#  'carrot (gajjar)': 321,
#  'button mushrooms': 174,
#  'dark soy sauce': 24,
#  'bean paste': 1,
#  'cheese crumble': 1,
#  'ginger green chilli': 1,
#  'mango powder powder': 2,
#  'elephant yam': 1,
#  'asafetida': 24,
#  'kali urad dal (split)': 1,
#  'rice noodles': 3,
#  'baby corn': 37,
#  'capsicum (red)': 7,
#  'capsicum (yellow)': 2,
#  'capsicum (green)': 20,
#  'thai basil leaves': 7,
#  'green onion': 6,
#  'brown sugar': 1,
#  'fish sauce': 13,
#  'sriracha sauce': 27,
#  'shrimps prawns': 1,
#  'garlic paste': 59,
#  'green chilli paste': 33,
#  'walnuts': 97,
#  'dried figs': 15,
#  'flax seeds': 13,
#  'gram chicken': 1,
#  'badam (almond) paste': 2,
#  'sooji (semolina rava)': 136,
#  'ghee roasting the rava': 1,
#  'saffron strands ( using mortar pestle)': 1,
#  'mixed dry fruits': 7,
#  'chicken breasts': 94,
#  'cardamom': 27,
#  'star anise': 89,
#  'black pepper': 9,
#  'sprig green coriander': 19,
#  'sprig mint': 5,
#  'cottage cheese cube': 1,
#  'kasoori methi': 6,
#  'salt oil': 7,
#  'goond (edible gum)': 1,
#  'dry coconut (kopra)': 49,
#  'chana lentils': 1,
#  'spoon turmeric powder': 4,
#  'coriander leaves': 16,
#  'tulsi (holy basil)': 6,
#  'dry ginger powder': 78,
#  'palm sugar (panakalkandu)': 1,
#  'del monte sandwich': 4,
#  'gram dal (pottukadalai)': 35,
#  'palm jaggery date palm jaggery': 2,
#  'gingelly oil': 24,
#  'pearl onion (sambar onion)': 83,
#  'urad dal papad': 1,
#  'basmati rice hour': 1,
#  'dates': 61,
#  'onion paste': 24,
#  'tomato paste': 8,
#  'kabuli chana (white chickpeas)': 77,
#  'brown cardamom (badi elaichi)': 8,
#  'black salt': 71,
#  'peanuts roast': 6,
#  'cloves garlic un': 1,
#  'banana': 46,
#  'suran': 5,
#  'black gram': 3,
#  'ginger chooped': 1,
#  'gram curd': 1,
#  'cashews almonds (paste)': 1,
#  'water make pliable dough': 1,
#  'red chilli powder green chillies': 1,
#  'mixed nuts': 30,
#  'taco shells': 8,
#  'hariyali chicken tikka': 1,
#  'summer salad': 3,
#  're beans': 7,
#  'tomato salsa': 15,
#  'trumpet': 3,
#  'spoon coriander powder': 2,
#  'basmati rice par spices infused water (spices include cinnamon': 1,
#  'soy (nuggets)': 18,
#  'biryani masala': 5,
#  'brinjal (baingan eggplant)': 103,
#  'iceberg lettuce': 37,
#  'chicken breasts cm cubes': 2,
#  'chilli vinegar': 25,
#  'vanilla drops': 3,
#  'orange': 53,
#  'orange two': 1,
#  'wheat brown bread': 100,
#  'elephant yam (suransenairatalu)': 31,
#  'chicken breast': 1,
#  'bottle gourd (lauki) discs': 1,
#  'chicken breasts th': 2,
#  'tomato pulp': 8,
#  'hummus': 5,
#  'tzatziki': 6,
#  'ghee parathas': 1,
#  'ghee oil': 44,
#  'ragi flour (finger millet nagli)': 46,
#  'dill leaves': 39,
#  'sweet potatoes': 33,
#  'rasam powder': 17,
#  'oreo biscuits': 5,
#  'vanilla ice': 7,
#  'scoops': 1,
#  'chocolate sauce': 7,
#  'heavy whipping': 60,
#  '': 58,
#  'del monte cheesy garlic mayo': 10,
#  'lemon wedged': 2,
#  'onion red': 4,
#  'yogurt': 16,
#  'salt ghee': 2,
#  'aar maach (fish) (rohu katla)': 1,
#  'coriander (dhania) leaves sprigs': 57,
#  'green amaranth leaves': 11,
#  'tamarind pulp': 4,
#  'methi powder (fenugreek powder)': 10,
#  'kidney beans': 3,
#  'button mushrooms quatered': 5,
#  'curd vada': 1,
#  'papdi puris': 2,
#  'boondi sev': 1,
#  'wheat grass powder': 2,
#  'lemon juiced': 52,
#  'kabuli channa soak then boil': 1,
#  'gingerpaste': 1,
#  'chana masala powder': 6,
#  'spoon cumin powder': 2,
#  'amchoor powder': 1,
#  'kachris': 1,
#  'gms cheese': 1,
#  'ginger grated': 3,
#  'cumin powder baked': 1,
#  'salt per': 11,
#  'oil green coriander finely': 1,
#  'lentil water chana lentil water': 1,
#  'black peppers': 3,
#  'cumin': 22,
#  'curry leaves break': 3,
#  'tamarind paste reduce you like': 1,
#  'goda masala': 2,
#  'cabbage': 23,
#  'mint leaves (pudina) sprigs': 7,
#  'vegetable stock': 69,
#  'carrots': 22,
#  'basmati rice (or other rice)': 1,
#  'cauliflower (gobi) florets': 36,
#  'potatoes boil remove the skin': 1,
#  'stock green coriander': 1,
#  'spinach leaves (palak) bunch': 6,
#  'pheni roll': 1,
#  'almond meal (badam powder)': 30,
#  'papad urad dal': 1,
#  'tamarind lemon': 36,
#  'horsepowder': 1,
#  'gram lentils': 2,
#  'tomato pasta sauce store bought': 1,
#  'eggs flaxmeal egg replacer': 2,
#  'red food color (only )': 1,
#  'chocolate ganache': 4,
#  'flax seed powder (flax meal)': 29,
#  'pistachios': 136,
#  'ghee vegetable oil': 1,
#  'tindora (dondakaya kovakkai)verticy': 1,
#  'bay leaves': 14,
#  'celery': 30,
#  'large cardamom': 4,
#  'mace': 3,
#  'st flowers': 1,
#  'star anis': 4,
#  'spoon nutmeg powder': 1,
#  'chicken sausage': 2,
#  'sprig mint leaves (pudina)': 66,
#  'sprig spring onion (bulb greens)': 17,
#  'feta cheese': 41,
#  'lemon juice drops': 4,
#  'fruit (pineapple': 1,
#  'coconut take': 1,
#  'dry red peppers break': 1,
#  'potatoes (aloo) cubes': 5,
#  'coriander (dhania) leavesfor': 20,
#  'sunflower oil the toast': 1,
#  'kashmiri dry red chillies hour': 1,
#  'garlic cloves': 21,
#  'water grind': 2,
#  'water enough boiling potatoes': 1,
#  'pointed gourd (parval)': 9,
#  'lotus stem': 7,
#  'instant oats (oatmeal)': 113,
#  'wheat flakes (cereal)': 3,
#  'pine nuts': 5,
#  'pumpkin seeds': 12,
#  'dates (dried s)': 1,
#  'dried raspberries': 2,
#  'raisins (sultana)': 1,
#  'nutmeg powder': 75,
#  'mustard greens': 6,
#  'mint leaves (pudina) fistful': 1,
#  'gawar phali (kothavarangai cluster beans)': 12,
#  'stalks lemongrass': 9,
#  'okra (okra)': 1,
#  'garlic finely': 1,
#  'cottage cheese ed': 1,
#  'mango powder': 8,
#  'wood apple (bael fruit)': 1,
#  'jaggery sugar': 5,
#  'mango (ripe)': 59,
#  'peanuts (moongphali) dry': 2,
#  'kataifi dough ready': 1,
#  'rose water': 42,
#  'icing sugar': 49,
#  'thandai masala': 6,
#  'dried rose': 12,
#  'khoya (mawa)': 37,
#  'snake gourd (pudulangai)(approximately )': 1,
#  'aloo bhujia': 3,
#  'ginger ground': 5,
#  'moth sprouts (matki)': 3,
#  'spinach leaves (palak) ground': 1,
#  'banana flower (vazhaipoo) ripe': 1,
#  'salt some the chana dal': 1,
#  'caster sugar ( sugar)': 2,
#  'bhindi (lady fingerokra)': 47,
#  'sprig coriander (dhania) leavesfor': 8,
#  'ginger juliennes ( th)': 1,
#  'chicken thighs skinless bless': 1,
#  'tomato desseded': 1,
#  'amla (nellikai gooseberry)': 13,
#  'brinjal': 3,
#  'colocasia root (arbi)': 19,
#  'salt salt': 10,
#  'gunde (bird lime)': 2,
#  'jackfruit (kathal) junks': 1,
#  'rajma (large kidney beans)': 55,
#  'sour': 29,
#  'make tomatopuree': 1,
#  'sprigs mint': 2,
#  'milk luke': 3,
#  'hy jaggery sugar': 1,
#  'chocolate chips dark white': 1,
#  'butter ricotta cheese': 1,
#  'cheese soft paneer': 1,
#  'orange orange': 2,
#  'sugar on top': 1,
#  'baby corn be': 1,
#  'pizza': 6,
#  'bajra flour ( pearl millet)': 31,
#  'ghee greasing': 3,
#  'spaghetti pasta': 19,
#  'spinach amaranth leaves': 1,
#  'cloves garlic( size)': 1,
#  'lemon': 134,
#  'sprigs curry leaves': 5,
#  'water knead': 38,
#  'pani puris': 6,
#  'green moong sproutsgreen moong sprouts': 1,
#  'mango (raw)': 62,
#  'quinoa': 32,
#  'del monte corn kernels': 9,
#  'apricots': 11,
#  'brown sugar (demerara sugar)': 133,
#  'butter cold': 13,
#  'pecans': 7,
#  'coffee decoction': 4,
#  'basella (malabar spinach)': 1,
#  'enos fruit salt baking powder': 4,
#  'red chilli powder the batter': 1,
#  'figs': 11,
#  'enos fruit salt soda': 2,
#  'sunflower oil ¼ vadis': 1,
#  'fennel powder': 39,
#  'aam papad (sun dried mango)': 2,
#  'water (preferably)': 1,
#  'coconut yogurt': 1,
#  'edible silver foilleaf (chandi ka vark)': 8,
#  'pineapple': 46,
#  'coconut oil cold pressed': 2,
#  'bajra (seeds)': 9,
#  'jowar seeds': 9,
#  'masoor dal': 56,
#  'sunflower oil the pakodas': 1,
#  'pomegranate': 7,
#  'cumin powder take out': 2,
#  'sesame seeds (til seeds) dry': 5,
#  'salt you can the normal salt too': 1,
#  'banana par': 1,
#  'gram spaghetti pasta': 1,
#  'sprigs coriander (dhania) leaves': 10,
#  'bread cubes (croutons) seasd garlic dried rosemary': 1,
#  'gram flour': 23,
#  'rice fluffy': 1,
#  'rajma (large kidney beans) but not': 1,
#  'chipotle chillies peppers (or flat red chilli flakes)': 1,
#  'red bell pepper (capsicum) (or other vegetables that can be stir )': 1,
#  'del monte corn kernels fire': 1,
#  'cheddar cheese mexican cheese': 2,
#  'lettuce leaves': 11,
#  'black olives': 51,
#  'guacamole recipes': 1,
#  'almonds': 4,
#  'saffron': 3,
#  'almond silver': 1,
#  'corn flour mixed water': 3,
#  'almonds (badam)': 25,
#  'tender coconut water': 10,
#  'tender coconut meat': 1,
#  'condensed milk': 55,
#  'hy glazing (optional)': 1,
#  'ice': 9,
#  'c (optional)': 1,
#  'white vinegar lime juice': 1,
#  'yellow food colour': 4,
#  'salt sugar per preference': 1,
#  'raita masala': 1,
#  'instant coffee powder': 24,
#  'ghee roasting': 4,
#  'malabar spinach leaves stalks': 1,
#  'ku (parangikai pumpkin)': 65,
#  'mustard oil vegetable oil': 2,
#  'lemon juice lemon': 11,
#  'egg (or yogurt)': 1,
#  'parsley': 11,
#  'sprig chives(or other herb)': 1,
#  'peanut oil pan': 2,
#  'bamboo shoots': 2,
#  'button mushrooms cremini mushrooms': 1,
#  'red yellow green bell peppers (capsicum)': 21,
#  'red matta rice par': 3,
#  'idli dosa batter': 23,
#  'rice par': 2,
#  'poha (flattened rice) ( variety)': 1,
#  'buttermilk sour': 2,
#  'soda': 28,
#  'butter loni (white butter)': 1,
#  'paneer cubes': 10,
#  'barley flour': 1,
#  'instant coffee powder ( based on its strength)': 1,
#  'chicken (chicken bs gives better )': 1,
#  'spinach leaves (palak) ed': 1,
#  'cloves garlic pound': 8,
#  'sprig natural bourbon vanilla': 3,
#  'strained from water': 1,
#  'rasam powder red chilli powder': 2,
#  'fenugreek seeds': 25,
#  'green coffee beans ground': 1,
#  'barley (seeds)': 9,
#  'green peas (matar) frozen': 5,
#  'rocket leaves spinach leaves': 1,
#  'thyme leaves': 19,
#  'spirulina': 6,
#  'pasta': 2,
#  'coconut milk toddy': 3,
#  'coconut grated': 3,
#  'peanuts (moongphali) ground': 5,
#  'chicken thighswings': 1,
#  'garlic minced': 1,
#  'sesame (gingelly) oil olive oil': 1,
#  'pomegranate juice squeezed': 2,
#  'orange juice': 44,
#  'salt rimming the glass (margarita salt': 2,
#  'tequila': 2,
#  'triple sec': 2,
#  'rolled oats instant oats': 20,
#  'green peas boil': 3,
#  'phulka': 1,
#  'hazelnut meal (powder)': 1,
#  'paneer crumpled': 1,
#  'pav buns butter': 1,
#  'baby corn length wise': 2,
#  'tofu paneer': 1,
#  'light soy sauce': 12,
#  'red chilli paste': 7,
#  'rice vinegar': 17,
#  'peanuts (moongphali) salted': 1,
#  'orange marmalade jam': 2,
#  'papaya': 20,
#  'lentils': 2,
#  'aniseed': 1,
#  'kalonji seeds': 5,
#  'jowar flour (sorghum)': 30,
#  'cherry tomato': 53,
#  'black eyed beans (lobia)': 31,
#  'red yellow green bell pepper (capsicum)': 18,
#  'ginger (fine)': 1,
#  'red chilli powder red chilli flakes': 1,
#  'bless chicken (': 1,
#  'corn flakes coarse powder': 1,
#  'wheat brown bread preferably dayold bread': 1,
#  'sprig thyme leaves oregano herbs choice': 1,
#  'black pepper powder (or red chilli flakes)': 1,
#  'cheddar cheese topping': 1,
#  'butter greasing the baking dish': 1,
#  'ghee the parathas': 5,
#  'tea monk seiki peppermint green tea': 1,
#  'wheat bread crumbs bread crumbs': 1,
#  'pink masoor dal (split)': 8,
#  'drumstick leaves (moringamurungai keerai)': 17,
#  'ginger ground paste': 6,
#  'sabudana (tapioca pearls)': 21,
#  'lemon juice ( needed)': 1,
#  'bananas': 81,
#  'flour (maida) plus': 3,
#  'butter cold pea': 1,
#  'water temperature be ice cold plus needed': 1,
#  '(used amul': 1,
#  'india)': 1,
#  'dark chocolate (used bournville)': 1,
#  'green moong dal': 51,
#  'kali urad dal': 1,
#  'masoor dal (split)': 2,
#  'rajma': 1,
#  'kabuli chana': 1,
#  'yellow moong dal': 7,
#  'ginger finely': 1,
#  'dal sugar': 1,
#  'sprouted moong': 3,
#  'chow chow': 1,
#  'sesame oil oil': 2,
#  'red chilli': 21,
#  'black urad dal': 19,
#  'gulkand': 11,
#  'flour (maida) rolling': 1,
#  'baby spinach': 6,
#  'black rice': 11,
#  'button mushrooms (button crimini variety)': 2,
#  'parmesan cheese (reduced fat)': 2,
#  'mascarp cheese': 7,
#  'cheese (reduced fat fat free)': 2,
#  'mozzarella cheese (partskimmed)': 2,
#  'tomato pulp scooped out': 1,
#  'mutton kheema': 4,
#  'black gram soak cook till becomes soft': 1,
#  'spoon coconut': 1,
#  'sprig basil leaves': 45,
#  'mustard sauce': 18,
#  'apple cider vinegar': 15,
#  'black eyed beans (lobia) two': 1,
#  'dry red chillies gundu milagai)': 1,
#  'sunflower seeds': 15,
#  'melon seeds': 13,
#  'curry leaves pat dried': 2,
#  'del monte mint mayo': 10,
#  'lemon squeezed': 6,
#  'sev finer': 1,
#  'chiroti rava': 6,
#  'cajun spice mix': 1,
#  'garlic (or garlic paste)': 1,
#  'green moong dal (split)': 12,
#  'sweetened coconut flakes': 1,
#  'chocolate bar': 8,
#  'ginger juliennes': 5,
#  'nutralite classic parathas': 1,
#  'seer fish': 4,
#  'aachi fish masala': 1,
#  'kokum (malabar tamarind)': 26,
#  'wheat flour rolling': 1,
#  'arhar dal (split toor dal) ground': 1,
#  'green chillies can also reduce': 1,
#  'amaranth leaves': 2,
#  'dried shrimps': 1,
#  'fish sauce soya sauce': 1,
#  'papaya unripened': 1,
#  'palm sugar brown sugar': 2,
#  'sunflower oil butter': 6,
#  'tapioca root': 4,
#  'butter have used salted butter': 1,
#  'matcha powder (japanese green tea)': 1,
#  'butter greasing': 5,
#  'red baby radish': 3,
#  'flour ( flour)': 4,
#  'wheat bran': 9,
#  'tsp dry yeast': 1,
#  'cucumbers': 10,
#  'red onion': 28,
#  'black peppercorns cracked': 2,
#  'lemon juice large limes': 1,
#  'tahini': 17,
#  'sun dried tomato dipped olive oil': 1,
#  'pomegranate sauce recipe': 1,
#  'dry yeast water': 1,
#  'turnips': 6,
#  'mutton': 51,
#  'poppy seeds paste': 4,
#  'english cucumber': 14,
#  'tofu rectangular shapes': 1,
#  'fish fillet': 7,
#  'mixed sprouts bowls': 1,
#  'hung curd (greek yogurt) fatfree': 1,
#  'egg white': 12,
#  'muesli': 20,
#  'strawberries': 53,
#  'chia seeds': 34,
#  'digestive biscuit': 6,
#  'dark chocolate curls': 1,
#  'kala jeera': 11,
#  'sprig tulsi (holy basil)': 4,
#  'betel leaves (paan)': 4,
#  'ghee plus': 2,
#  'pepper salt ( black pepper)': 1,
#  'lasagna sheets the that needs no pre': 1,
#  'bottle gourd (lauki)': 50,
#  'multigrain flour besan': 1,
#  'cashew nuts water': 3,
#  'prawns shelled': 1,
#  'leek': 9,
#  'almond essence (badam essence)': 5,
#  'plums': 2,
#  'coconut oil other oil': 2,
#  'foxtail millet': 23,
#  'ghee bfor': 1,
#  'dates water': 1,
#  'multigrain digestive oat biscuits': 5,
#  'pie crust': 4,
#  'potatoes (aloo) firm': 1,
#  'cheese (like flavored herbed cheese)': 1,
#  'nutralite classic': 14,
#  'salmon fillet': 1,
#  'sambal oelek': 1,
#  'sweet potatoes th': 1,
#  'eggs egg separated': 1,
#  'nutralite garlic oregano': 15,
#  'apples': 26,
#  'wheat noodles': 6,
#  'stalks spring onion greens': 7,
#  'pearl onion': 1,
#  'jackfruit (kathal)': 13,
#  'gilka (spongesilk squash)': 2,
#  'groundnut powder': 10,
#  'sesame powder': 4,
#  'maharashtrian goda masala': 20,
#  'tsp cinnamon powder': 1,
#  'karela (bitter gourd pavakkai) th': 2,
#  'oil ghee': 4,
#  'neem leaves': 2,
#  'sunflower oil saffola': 3,
#  'egg noodles': 4,
#  'nendra pazham banana (ripe)': 3,
#  'sunflower oil tempering': 4,
#  'thyme leaves dried': 2,
#  'curry powder': 13,
#  'saltlemon juice': 1,
#  'wood': 1,
#  'oil curry leaves': 1,
#  'dates seedless': 5,
#  'ghee greasing the plate': 3,
#  'coconut milk coconut': 1,
#  'rye powder': 1,
#  'poppy seeds powder': 1,
#  'garlic bud': 1,
#  'banana leaves steamer put': 1,
#  'banana leaves cook on low flame': 1,
#  'oil grease': 1,
#  'sunflower oil drops greasing': 3,
#  'puff pastry sheet': 9,
#  'apple': 43,
#  'broccoli florets approximately': 2,
#  'mixed vegetables (french beans': 2,
#  'fish': 6,
#  'medu vada': 1,
#  'gram butter': 8,
#  'gram sugar': 2,
#  'urad dal flour': 7,
#  'sesame (white)': 2,
#  'spoon tomato sauce': 1,
#  'prawns marinate': 1,
#  'oil per the usage': 1,
#  'dal sugar powder': 2,
#  'pav buns': 11,
#  'herb butter toasting the buns': 1,
#  'lahsun ki chutney (red garlic chutney)': 6,
#  'ginger powder': 1,
#  'ghee sesame oil': 3,
#  'virgin olive oil the patties': 1,
#  'shrikhand': 1,
#  'mixed fruits assortment fruits like': 1,
#  'potato masala': 3,
#  'garlic chutney': 1,
#  'potato': 10,
#  'green peas (matar) pod': 1,
#  'paneer ness': 2,
#  'ghee butter greasing': 1,
#  'gram chenna': 1,
#  'green bell pepper (capsicum) colour': 1,
#  'sunflower oil greasing the': 1,
#  'badam (almond) an hour': 1,
#  'orange pulp': 2,
#  'badam (almond) a': 2,
#  'mixed fruits (used figs': 1,
#  'green chawli beans (yard beanskaramanibarbati)': 4,
#  'basmati rice grain rice': 1,
#  'mixed vegetables (potato': 2,
#  'anardana powder (pomegranate seed powder) seeds': 1,
#  'ghee the malpua': 1,
#  'avocado': 27,
#  'virgin olive oil butter': 6,
#  'sprigs mint leaves (pudina)': 1,
#  'sprigs parsley leaves': 1,
#  'spinach basil sauce': 1,
#  'mixed herbs (dried)': 62,
#  'sunflower oil salt': 1,
#  'indian borage (doddapatre)': 2,
#  'tamarind (sm lemon size)': 1,
#  'mixed vegetables': 7,
#  'tomato ripe': 6,
#  'chicken curry': 9,
#  'tamarind.': 1,
#  'kashmiri dry red chilli': 8,
#  'lotus stem (nadru kamal kakdi)': 1,
#  'mint powder (pudina)': 3,
#  'chicken stock chicken stock cube water': 1,
#  'sherry white wine': 1,
#  'corn flour dissolved': 2,
#  'chicken breasts skinless bless': 1,
#  'bok choy heads': 1,
#  'rice water': 3,
#  'baby potatoes quatered': 1,
#  'dhansak masala': 5,
#  'carrot (gajjar) diagony': 5,
#  'soybeans (whole soya dal)': 8,
#  'green chickpeas frozen': 1,
#  'rice min': 2,
#  'double beans': 1,
#  'mango (raw) the skin': 1,
#  'singhade (water chestnut)': 5,
#  'rice ground': 2,
#  'virgin olive oil brushing': 1,
#  'confectirs sugar': 8,
#  'basmati rice mins': 1,
#  'egg only': 1,
#  'sprig basil leaves ground paste': 1,
#  'knol khol (ganth gobikadam)': 3,
#  'sunflower oil ghee': 25,
#  'phool makhana (lotus seeds)': 16,
#  'red chilli sauce (or birds eye chilli sauce)': 1,
#  'sunflower oil the pickle oil flavour': 1,
#  'clove cloves (laung)': 2,
#  'potato (aloo) salt water': 1,
#  'rajgira flour (amaranth flour)': 10,
#  'black peppercorns ground': 27,
#  'britannia cheese four pepper tango': 5,
#  'cheese over the bread': 1,
#  'suran boil': 1,
#  'banana boil': 1,
#  'amchur powder': 3,
#  'oats coat': 1,
#  'black chilli powder': 1,
#  'cocoa powder mixed tbsp. water': 1,
#  'strawberry compote': 4,
#  'butterscotch chips almonds': 1,
#  'beer': 2,
#  'watermelon': 15,
#  'black grapes': 5,
#  'tikka masala': 1,
#  'kashmiri dry red chillies': 16,
#  'condensed milk sweetened': 6,
#  'coconut strands': 1,
#  'napa cabbage': 1,
#  'carrot (gajjar) stripes': 1,
#  'arabic now': 1,
#  'tamarind malabar': 2,
#  'coconut scrape': 1,
#  'dry red chillies break': 2,
#  'mutton (used shanks)': 1,
#  'saffron strands milk': 9,
#  'ginger julienne': 5,
#  'shiitake mushrooms (or oyster mushrooms)': 1,
#  'oyster sauce': 2,
#  'bananas nendra variety': 1,
#  'dark chocolate chips': 8,
#  'eggs egg': 2,
#  'kabuli channa': 1,
#  'green capsicum': 2,
#  'kasuri methi': 8,
#  'rice cook': 2,
#  'ghee coriander': 1,
#  'dates ( dates': 1,
#  'cocoa powder (you can semi sweet cocoa also)': 1,
#  'gwar pods': 3,
#  'radishes': 3,
#  'cinnamon stick': 18,
#  'cumin (jeera) seeds': 22,
#  'coriander (dhania) powder': 23,
#  'green seedless grapes': 9,
#  'peanuts (moongphali) mortar pestle': 1,
#  'gram flour (sattu ka atta)': 6,
#  'pickle red chilli pickle': 1,
#  'sprig dill leaves': 9,
#  'yellow moong dal (split) mins': 1,
#  'bhindi (lady fingerokra) stripes': 1,
#  'black eyed beans (lobia) least': 1,
#  'cashews soak water': 1,
#  ...}

# %%
len(count)
# Out:
# 5264

# %%
count
# Out:
# {'karela (bitter gourd pavakkai)': 31,
#  'salt': 5426,
#  'onion': 2345,
#  'gram flour (besan)': 320,
#  'turmeric powder (haldi)': 1917,
#  'red chilli powder': 1696,
#  'cumin seeds (jeera)': 1310,
#  'coriander powder (dhania)': 733,
#  'amchur (dry mango powder)': 204,
#  'sunflower oil': 2273,
#  'rice': 242,
#  'tomato': 1347,
#  'bc belle bhat powder': 1,
#  'chickpea lentils': 3,
#  'cumin seeds': 125,
#  'white urad dal': 79,
#  'mustard': 84,
#  'green chilli': 649,
#  'dry red chilli': 289,
#  'cashew peanuts': 1,
#  'oilasafoetida': 1,
#  'rice vermicelli noodles (thin)': 9,
#  'carrots (gajjar)': 177,
#  'green peas (matar)': 225,
#  'green chillies': 1299,
#  'asafoetida (hing)': 855,
#  'mustard seeds': 1077,
#  'white urad dal (split)': 367,
#  'ghee': 865,
#  'sprig curry leaves': 788,
#  'lemon juice': 791,
#  'chicken': 99,
#  'ginger': 1423,
#  'cloves garlic': 1561,
#  'garam masala powder': 809,
#  'sesame (gingelly) oil': 161,
#  'methi seeds (fenugreek seeds)': 279,
#  'coriander (dhania) seeds': 305,
#  'dry red chillies': 656,
#  'fennel seeds (saunf)': 323,
#  'sorrel leaves (gongura)': 2,
#  'chana dal': 21,
#  'red chillies': 35,
#  'coriander seeds': 25,
#  'asafoetida': 75,
#  'oil': 207,
#  'sprig curry': 1,
#  'yellow moong dal (split)': 121,
#  'mint leaves (pudina)': 278,
#  'coriander (dhania) leaves': 819,
#  'water': 1140,
#  'cashew nuts': 305,
#  'black peppercorns': 451,
#  'vellai poosanikai (ash gourdwhite pumpkin)': 10,
#  'coconut': 778,
#  'tamarind water': 129,
#  'sesame seeds (til seeds)': 203,
#  'jaggery': 411,
#  'tortillas': 28,
#  'black beans': 8,
#  'spinach leaves (palak)': 114,
#  'sprig coriander (dhania) leaves': 449,
#  'rice brown rice': 2,
#  'spring onion greens': 94,
#  'cheddar cheese': 64,
#  'hung curd (greek yogurt)': 146,
#  'idli': 5,
#  'green bell pepper (capsicum)': 289,
#  'tomato ketchup': 68,
#  'cabbage leaves': 1,
#  'tamarind': 96,
#  'turmeric powder': 204,
#  'spoon oil': 1,
#  'rye': 35,
#  'dry beans (such cannellini soya beans)': 2,
#  'virgin olive oil': 715,
#  'clove garlic': 58,
#  'hy': 286,
#  'cumin powder (jeera)': 654,
#  'dried oregano': 223,
#  'red chilli powder cayenne pepper': 3,
#  'pepper ( pepper)': 1,
#  'burger buns': 10,
#  'jalapenos': 42,
#  'cheese': 126,
#  'potatoes (aloo) pressure': 1,
#  'egg': 166,
#  'wheat bread crumbs': 101,
#  'soy granules': 8,
#  'red chilli flakes': 280,
#  'tabasco original sauce': 34,
#  'arhar dal (split toor dal)': 160,
#  'aar maach (fish) rohu katla fish (cut steaks)': 1,
#  'bay leaves (tej patta)': 108,
#  'ginger paste': 77,
#  'mustard oil': 242,
#  'sugar': 1067,
#  'potatoes (aloo) skin': 10,
#  'milk': 614,
#  'black urad dal (split)': 51,
#  'tamarind paste': 115,
#  'eggs': 314,
#  'cinnamon stick (dalchini)': 509,
#  'bay leaf (tej patta)': 317,
#  'cloves (laung)': 428,
#  'curd': 569,
#  'gourd': 5,
#  'cucumber grind': 1,
#  'green': 2,
#  'green coriander': 42,
#  'cumin powder': 49,
#  'potatoes (aloo)': 290,
#  'garlic powder': 36,
#  'onion powder': 11,
#  'flour (maida)': 508,
#  'rice flour': 185,
#  'sunflower oil the r tots': 1,
#  'bay leaf break': 4,
#  'carrot': 14,
#  'green beans': 15,
#  'potatoes': 21,
#  'cloves': 3,
#  'cinnamon': 34,
#  'fennel': 9,
#  'pepper': 229,
#  'green peas': 20,
#  'mint leaves': 6,
#  'amla': 4,
#  'bud garlic': 10,
#  'mint': 7,
#  'coriander': 32,
#  'urad dal': 3,
#  'wheat flour': 462,
#  'cucumber': 114,
#  'ghee on thalipeeth': 1,
#  'submarine bread (subway bread) (flat breads foot s)': 1,
#  'green moong sprouts': 49,
#  'beetroot': 72,
#  'stalks spring onion (bulb greens)': 15,
#  'drumstick': 37,
#  'coconut oil': 168,
#  'mango pulp (puree)': 17,
#  'saffron strands': 167,
#  'badam (almond)': 206,
#  'milk luke cold milk': 1,
#  'ice cubes': 40,
#  'idli dosa mixture': 2,
#  'rice rava': 6,
#  'cardamom powder': 8,
#  'cardamom (elaichi) podsseeds': 426,
#  'cloves cloves (laung)': 13,
#  'mace (javitri)': 40,
#  'black cardamom (badi elaichi)': 102,
#  'kasuri methi (dried fenugreek leaves)': 132,
#  'kashmiri red chilli powder': 168,
#  'samosas mini': 1,
#  'baguette': 10,
#  'butter': 644,
#  'garlic': 267,
#  'red bell pepper (capsicum) (': 1,
#  'black pepper powder': 801,
#  'italian': 39,
#  'tomato pasta sauce': 24,
#  'ajwain (carom seeds)': 233,
#  'chana dal (bengal gram dal)': 282,
#  'sweet chutney (date tamarind)': 40,
#  'green chutney (coriander mint)': 50,
#  'pomegranate fruit kernels': 35,
#  'sev': 25,
#  'green beans (french beans)': 145,
#  'soy sauce': 208,
#  'thai sweet chilli sauce': 2,
#  'rice wine vinegar': 12,
#  'peanuts (moongphali)': 215,
#  'baking powder': 271,
#  'water make the dough': 2,
#  'sesame seeds (til seeds) white': 7,
#  'vanilla': 289,
#  'sundkai': 1,
#  'fenugreek': 5,
#  'arhar dal': 10,
#  'sambar powder': 93,
#  'coriander powder': 106,
#  'curry leaves': 373,
#  'cabbage (patta gobi muttaikose)': 109,
#  'spinach': 110,
#  'green chilli sauce': 25,
#  'cinnamon powder (dalchini)': 188,
#  'dark chocolate': 45,
#  'cocoa powder': 95,
#  'salted butter': 14,
#  'baking soda': 160,
#  'britannia': 48,
#  'caster sugar': 161,
#  'raspberries': 2,
#  'ada': 1,
#  'milk full': 10,
#  'cardamom powder (elaichi)': 307,
#  'tindora (dondakaya kovakkai)': 9,
#  'split methi seeds (methi kuria)': 3,
#  'split mustard seeds (rai kuria)': 4,
#  'chicken legs': 7,
#  'kalonji (onion nigella seeds)': 68,
#  'jackfruit seeds (kathal)': 8,
#  'coriander (dhania)': 141,
#  'eggplant': 10,
#  'sprigs coriander': 7,
#  'tea leaves': 4,
#  'mango': 10,
#  'kala chana (brown chickpeas)': 49,
#  'cheese flavoured': 1,
#  'broccoli': 84,
#  'red bell pepper (capsicum)': 206,
#  'sprig parsley leaves': 36,
#  'makki ka atta (yellow corn meal flour)': 24,
#  'methi leaves (fenugreek leaves)': 94,
#  'dry yeast': 95,
#  'brown rice': 26,
#  'oregano': 4,
#  'rosemary': 43,
#  'ridge gourd skin (turai peerkangai)': 2,
#  'wheat (dalia godumai rava)': 25,
#  'water make pakora batter': 2,
#  'enos fruit salt': 42,
#  'sunflower oil the pakoras': 2,
#  'paneer': 219,
#  'chaat masala powder': 214,
#  'coal giving smoked flavour': 3,
#  'jasmine rice': 3,
#  'sweet corn': 145,
#  'parsley leaves': 81,
#  'parmesan cheese': 88,
#  'mozzarella cheese': 120,
#  'eggs fork': 2,
#  'fish fillet basa': 1,
#  'prawns': 30,
#  'clamps': 1,
#  'baby potatoes': 40,
#  'paprika powder': 91,
#  'chicken stock': 11,
#  'coconut milk': 197,
#  'hakka noodles': 15,
#  'red chilli sauce': 115,
#  'white vinegar': 20,
#  'dry red chillies (chilli flakes)': 1,
#  'potato (aloo)': 166,
#  'panch phoran masala': 42,
#  'broccoli florets': 26,
#  'nutralite cheesy garlic mayo': 10,
#  'corn flour': 196,
#  'nutralite garlic oregano pan roasting': 1,
#  'mooli mullangi (radish)': 44,
#  'kasundi mustard sauce': 7,
#  'chakundar': 3,
#  'sesame oil': 13,
#  'sprig coriander': 13,
#  'ku (parangikai pumpkin) (red preferably)': 1,
#  'water dough': 2,
#  'sunflower oil rotis': 1,
#  'poppy seeds': 128,
#  'bless chicken': 34,
#  'sweet spicy red chilli sauce (tomato chilli sauce)': 24,
#  'spring onion (bulb greens)': 71,
#  'chinese spice powder': 10,
#  'white pepper powder': 25,
#  'egg noodles tossed oil': 1,
#  'classic mayonnaise (with egg)': 26,
#  'vinegar': 94,
#  'bay leaf': 27,
#  'lentil sugar': 13,
#  'ginger garlic paste': 314,
#  'tomato take': 1,
#  'capsicum (green) red yellow': 1,
#  'tofu': 62,
#  'pav bhaji masala': 21,
#  'french bread rye bread': 1,
#  'rocket leaves salad leaves the sandwich': 1,
#  'red wine vinaigrette': 20,
#  'dijon mustard': 22,
#  'cane sugar': 4,
#  'mooli mullangi (radish) purple': 1,
#  'vivatta maida': 50,
#  'cashews': 30,
#  'green zucchini': 65,
#  'dried thyme leaves': 56,
#  'black pepper corns': 52,
#  'basil leaves': 102,
#  'peanuts (moongphali) fistful': 1,
#  'hog plum (amtekai) (ambade)': 1,
#  'rice (raw rice)': 4,
#  'cauliflower (gobi)': 80,
#  'black pepper powder red chilli powder': 1,
#  'anardana powder (pomegranate seed powder)': 38,
#  'pomegranate molasses orhy': 1,
#  'herbs herbs choice like basil': 1,
#  'milk powder': 31,
#  'vivatta maida bread flour': 1,
#  'egg white brushing (or milk': 1,
#  'basmati rice': 103,
#  'yellow bell pepper (capsicum)': 78,
#  'sesame seeds (til seeds) mixed black white': 1,
#  'poha (flattened rice)': 46,
#  'nolen gur brown sugar': 1,
#  'mixed nuts almondscashews': 1,
#  'raisins': 159,
#  'bok choy': 9,
#  'carrot (gajjar)': 321,
#  'button mushrooms': 174,
#  'dark soy sauce': 24,
#  'bean paste': 1,
#  'cheese crumble': 1,
#  'ginger green chilli': 1,
#  'mango powder powder': 2,
#  'elephant yam': 1,
#  'asafetida': 24,
#  'kali urad dal (split)': 1,
#  'rice noodles': 3,
#  'baby corn': 37,
#  'capsicum (red)': 7,
#  'capsicum (yellow)': 2,
#  'capsicum (green)': 20,
#  'thai basil leaves': 7,
#  'green onion': 6,
#  'brown sugar': 1,
#  'fish sauce': 13,
#  'sriracha sauce': 27,
#  'shrimps prawns': 1,
#  'garlic paste': 59,
#  'green chilli paste': 33,
#  'walnuts': 97,
#  'dried figs': 15,
#  'flax seeds': 13,
#  'gram chicken': 1,
#  'badam (almond) paste': 2,
#  'sooji (semolina rava)': 136,
#  'ghee roasting the rava': 1,
#  'saffron strands ( using mortar pestle)': 1,
#  'mixed dry fruits': 7,
#  'chicken breasts': 94,
#  'cardamom': 27,
#  'star anise': 89,
#  'black pepper': 9,
#  'sprig green coriander': 19,
#  'sprig mint': 5,
#  'cottage cheese cube': 1,
#  'kasoori methi': 6,
#  'salt oil': 7,
#  'goond (edible gum)': 1,
#  'dry coconut (kopra)': 49,
#  'chana lentils': 1,
#  'spoon turmeric powder': 4,
#  'coriander leaves': 16,
#  'tulsi (holy basil)': 6,
#  'dry ginger powder': 78,
#  'palm sugar (panakalkandu)': 1,
#  'del monte sandwich': 4,
#  'gram dal (pottukadalai)': 35,
#  'palm jaggery date palm jaggery': 2,
#  'gingelly oil': 24,
#  'pearl onion (sambar onion)': 83,
#  'urad dal papad': 1,
#  'basmati rice hour': 1,
#  'dates': 61,
#  'onion paste': 24,
#  'tomato paste': 8,
#  'kabuli chana (white chickpeas)': 77,
#  'brown cardamom (badi elaichi)': 8,
#  'black salt': 71,
#  'peanuts roast': 6,
#  'cloves garlic un': 1,
#  'banana': 46,
#  'suran': 5,
#  'black gram': 3,
#  'ginger chooped': 1,
#  'gram curd': 1,
#  'cashews almonds (paste)': 1,
#  'water make pliable dough': 1,
#  'red chilli powder green chillies': 1,
#  'mixed nuts': 30,
#  'taco shells': 8,
#  'hariyali chicken tikka': 1,
#  'summer salad': 3,
#  're beans': 7,
#  'tomato salsa': 15,
#  'trumpet': 3,
#  'spoon coriander powder': 2,
#  'basmati rice par spices infused water (spices include cinnamon': 1,
#  'soy (nuggets)': 18,
#  'biryani masala': 5,
#  'brinjal (baingan eggplant)': 103,
#  'iceberg lettuce': 37,
#  'chicken breasts cm cubes': 2,
#  'chilli vinegar': 25,
#  'vanilla drops': 3,
#  'orange': 53,
#  'orange two': 1,
#  'wheat brown bread': 100,
#  'elephant yam (suransenairatalu)': 31,
#  'chicken breast': 1,
#  'bottle gourd (lauki) discs': 1,
#  'chicken breasts th': 2,
#  'tomato pulp': 8,
#  'hummus': 5,
#  'tzatziki': 6,
#  'ghee parathas': 1,
#  'ghee oil': 44,
#  'ragi flour (finger millet nagli)': 46,
#  'dill leaves': 39,
#  'sweet potatoes': 33,
#  'rasam powder': 17,
#  'oreo biscuits': 5,
#  'vanilla ice': 7,
#  'scoops': 1,
#  'chocolate sauce': 7,
#  'heavy whipping': 60,
#  '': 58,
#  'del monte cheesy garlic mayo': 10,
#  'lemon wedged': 2,
#  'onion red': 4,
#  'yogurt': 16,
#  'salt ghee': 2,
#  'aar maach (fish) (rohu katla)': 1,
#  'coriander (dhania) leaves sprigs': 57,
#  'green amaranth leaves': 11,
#  'tamarind pulp': 4,
#  'methi powder (fenugreek powder)': 10,
#  'kidney beans': 3,
#  'button mushrooms quatered': 5,
#  'curd vada': 1,
#  'papdi puris': 2,
#  'boondi sev': 1,
#  'wheat grass powder': 2,
#  'lemon juiced': 52,
#  'kabuli channa soak then boil': 1,
#  'gingerpaste': 1,
#  'chana masala powder': 6,
#  'spoon cumin powder': 2,
#  'amchoor powder': 1,
#  'kachris': 1,
#  'gms cheese': 1,
#  'ginger grated': 3,
#  'cumin powder baked': 1,
#  'salt per': 11,
#  'oil green coriander finely': 1,
#  'lentil water chana lentil water': 1,
#  'black peppers': 3,
#  'cumin': 22,
#  'curry leaves break': 3,
#  'tamarind paste reduce you like': 1,
#  'goda masala': 2,
#  'cabbage': 23,
#  'mint leaves (pudina) sprigs': 7,
#  'vegetable stock': 69,
#  'carrots': 22,
#  'basmati rice (or other rice)': 1,
#  'cauliflower (gobi) florets': 36,
#  'potatoes boil remove the skin': 1,
#  'stock green coriander': 1,
#  'spinach leaves (palak) bunch': 6,
#  'pheni roll': 1,
#  'almond meal (badam powder)': 30,
#  'papad urad dal': 1,
#  'tamarind lemon': 36,
#  'horsepowder': 1,
#  'gram lentils': 2,
#  'tomato pasta sauce store bought': 1,
#  'eggs flaxmeal egg replacer': 2,
#  'red food color (only )': 1,
#  'chocolate ganache': 4,
#  'flax seed powder (flax meal)': 29,
#  'pistachios': 136,
#  'ghee vegetable oil': 1,
#  'tindora (dondakaya kovakkai)verticy': 1,
#  'bay leaves': 14,
#  'celery': 30,
#  'large cardamom': 4,
#  'mace': 3,
#  'st flowers': 1,
#  'star anis': 4,
#  'spoon nutmeg powder': 1,
#  'chicken sausage': 2,
#  'sprig mint leaves (pudina)': 66,
#  'sprig spring onion (bulb greens)': 17,
#  'feta cheese': 41,
#  'lemon juice drops': 4,
#  'fruit (pineapple': 1,
#  'coconut take': 1,
#  'dry red peppers break': 1,
#  'potatoes (aloo) cubes': 5,
#  'coriander (dhania) leavesfor': 20,
#  'sunflower oil the toast': 1,
#  'kashmiri dry red chillies hour': 1,
#  'garlic cloves': 21,
#  'water grind': 2,
#  'water enough boiling potatoes': 1,
#  'pointed gourd (parval)': 9,
#  'lotus stem': 7,
#  'instant oats (oatmeal)': 113,
#  'wheat flakes (cereal)': 3,
#  'pine nuts': 5,
#  'pumpkin seeds': 12,
#  'dates (dried s)': 1,
#  'dried raspberries': 2,
#  'raisins (sultana)': 1,
#  'nutmeg powder': 75,
#  'mustard greens': 6,
#  'mint leaves (pudina) fistful': 1,
#  'gawar phali (kothavarangai cluster beans)': 12,
#  'stalks lemongrass': 9,
#  'okra (okra)': 1,
#  'garlic finely': 1,
#  'cottage cheese ed': 1,
#  'mango powder': 8,
#  'wood apple (bael fruit)': 1,
#  'jaggery sugar': 5,
#  'mango (ripe)': 59,
#  'peanuts (moongphali) dry': 2,
#  'kataifi dough ready': 1,
#  'rose water': 42,
#  'icing sugar': 49,
#  'thandai masala': 6,
#  'dried rose': 12,
#  'khoya (mawa)': 37,
#  'snake gourd (pudulangai)(approximately )': 1,
#  'aloo bhujia': 3,
#  'ginger ground': 5,
#  'moth sprouts (matki)': 3,
#  'spinach leaves (palak) ground': 1,
#  'banana flower (vazhaipoo) ripe': 1,
#  'salt some the chana dal': 1,
#  'caster sugar ( sugar)': 2,
#  'bhindi (lady fingerokra)': 47,
#  'sprig coriander (dhania) leavesfor': 8,
#  'ginger juliennes ( th)': 1,
#  'chicken thighs skinless bless': 1,
#  'tomato desseded': 1,
#  'amla (nellikai gooseberry)': 13,
#  'brinjal': 3,
#  'colocasia root (arbi)': 19,
#  'salt salt': 10,
#  'gunde (bird lime)': 2,
#  'jackfruit (kathal) junks': 1,
#  'rajma (large kidney beans)': 55,
#  'sour': 29,
#  'make tomatopuree': 1,
#  'sprigs mint': 2,
#  'milk luke': 3,
#  'hy jaggery sugar': 1,
#  'chocolate chips dark white': 1,
#  'butter ricotta cheese': 1,
#  'cheese soft paneer': 1,
#  'orange orange': 2,
#  'sugar on top': 1,
#  'baby corn be': 1,
#  'pizza': 6,
#  'bajra flour ( pearl millet)': 31,
#  'ghee greasing': 3,
#  'spaghetti pasta': 19,
#  'spinach amaranth leaves': 1,
#  'cloves garlic( size)': 1,
#  'lemon': 134,
#  'sprigs curry leaves': 5,
#  'water knead': 38,
#  'pani puris': 6,
#  'green moong sproutsgreen moong sprouts': 1,
#  'mango (raw)': 62,
#  'quinoa': 32,
#  'del monte corn kernels': 9,
#  'apricots': 11,
#  'brown sugar (demerara sugar)': 133,
#  'butter cold': 13,
#  'pecans': 7,
#  'coffee decoction': 4,
#  'basella (malabar spinach)': 1,
#  'enos fruit salt baking powder': 4,
#  'red chilli powder the batter': 1,
#  'figs': 11,
#  'enos fruit salt soda': 2,
#  'sunflower oil ¼ vadis': 1,
#  'fennel powder': 39,
#  'aam papad (sun dried mango)': 2,
#  'water (preferably)': 1,
#  'coconut yogurt': 1,
#  'edible silver foilleaf (chandi ka vark)': 8,
#  'pineapple': 46,
#  'coconut oil cold pressed': 2,
#  'bajra (seeds)': 9,
#  'jowar seeds': 9,
#  'masoor dal': 56,
#  'sunflower oil the pakodas': 1,
#  'pomegranate': 7,
#  'cumin powder take out': 2,
#  'sesame seeds (til seeds) dry': 5,
#  'salt you can the normal salt too': 1,
#  'banana par': 1,
#  'gram spaghetti pasta': 1,
#  'sprigs coriander (dhania) leaves': 10,
#  'bread cubes (croutons) seasd garlic dried rosemary': 1,
#  'gram flour': 23,
#  'rice fluffy': 1,
#  'rajma (large kidney beans) but not': 1,
#  'chipotle chillies peppers (or flat red chilli flakes)': 1,
#  'red bell pepper (capsicum) (or other vegetables that can be stir )': 1,
#  'del monte corn kernels fire': 1,
#  'cheddar cheese mexican cheese': 2,
#  'lettuce leaves': 11,
#  'black olives': 51,
#  'guacamole recipes': 1,
#  'almonds': 4,
#  'saffron': 3,
#  'almond silver': 1,
#  'corn flour mixed water': 3,
#  'almonds (badam)': 25,
#  'tender coconut water': 10,
#  'tender coconut meat': 1,
#  'condensed milk': 55,
#  'hy glazing (optional)': 1,
#  'ice': 9,
#  'c (optional)': 1,
#  'white vinegar lime juice': 1,
#  'yellow food colour': 4,
#  'salt sugar per preference': 1,
#  'raita masala': 1,
#  'instant coffee powder': 24,
#  'ghee roasting': 4,
#  'malabar spinach leaves stalks': 1,
#  'ku (parangikai pumpkin)': 65,
#  'mustard oil vegetable oil': 2,
#  'lemon juice lemon': 11,
#  'egg (or yogurt)': 1,
#  'parsley': 11,
#  'sprig chives(or other herb)': 1,
#  'peanut oil pan': 2,
#  'bamboo shoots': 2,
#  'button mushrooms cremini mushrooms': 1,
#  'red yellow green bell peppers (capsicum)': 21,
#  'red matta rice par': 3,
#  'idli dosa batter': 23,
#  'rice par': 2,
#  'poha (flattened rice) ( variety)': 1,
#  'buttermilk sour': 2,
#  'soda': 28,
#  'butter loni (white butter)': 1,
#  'paneer cubes': 10,
#  'barley flour': 1,
#  'instant coffee powder ( based on its strength)': 1,
#  'chicken (chicken bs gives better )': 1,
#  'spinach leaves (palak) ed': 1,
#  'cloves garlic pound': 8,
#  'sprig natural bourbon vanilla': 3,
#  'strained from water': 1,
#  'rasam powder red chilli powder': 2,
#  'fenugreek seeds': 25,
#  'green coffee beans ground': 1,
#  'barley (seeds)': 9,
#  'green peas (matar) frozen': 5,
#  'rocket leaves spinach leaves': 1,
#  'thyme leaves': 19,
#  'spirulina': 6,
#  'pasta': 2,
#  'coconut milk toddy': 3,
#  'coconut grated': 3,
#  'peanuts (moongphali) ground': 5,
#  'chicken thighswings': 1,
#  'garlic minced': 1,
#  'sesame (gingelly) oil olive oil': 1,
#  'pomegranate juice squeezed': 2,
#  'orange juice': 44,
#  'salt rimming the glass (margarita salt': 2,
#  'tequila': 2,
#  'triple sec': 2,
#  'rolled oats instant oats': 20,
#  'green peas boil': 3,
#  'phulka': 1,
#  'hazelnut meal (powder)': 1,
#  'paneer crumpled': 1,
#  'pav buns butter': 1,
#  'baby corn length wise': 2,
#  'tofu paneer': 1,
#  'light soy sauce': 12,
#  'red chilli paste': 7,
#  'rice vinegar': 17,
#  'peanuts (moongphali) salted': 1,
#  'orange marmalade jam': 2,
#  'papaya': 20,
#  'lentils': 2,
#  'aniseed': 1,
#  'kalonji seeds': 5,
#  'jowar flour (sorghum)': 30,
#  'cherry tomato': 53,
#  'black eyed beans (lobia)': 31,
#  'red yellow green bell pepper (capsicum)': 18,
#  'ginger (fine)': 1,
#  'red chilli powder red chilli flakes': 1,
#  'bless chicken (': 1,
#  'corn flakes coarse powder': 1,
#  'wheat brown bread preferably dayold bread': 1,
#  'sprig thyme leaves oregano herbs choice': 1,
#  'black pepper powder (or red chilli flakes)': 1,
#  'cheddar cheese topping': 1,
#  'butter greasing the baking dish': 1,
#  'ghee the parathas': 5,
#  'tea monk seiki peppermint green tea': 1,
#  'wheat bread crumbs bread crumbs': 1,
#  'pink masoor dal (split)': 8,
#  'drumstick leaves (moringamurungai keerai)': 17,
#  'ginger ground paste': 6,
#  'sabudana (tapioca pearls)': 21,
#  'lemon juice ( needed)': 1,
#  'bananas': 81,
#  'flour (maida) plus': 3,
#  'butter cold pea': 1,
#  'water temperature be ice cold plus needed': 1,
#  '(used amul': 1,
#  'india)': 1,
#  'dark chocolate (used bournville)': 1,
#  'green moong dal': 51,
#  'kali urad dal': 1,
#  'masoor dal (split)': 2,
#  'rajma': 1,
#  'kabuli chana': 1,
#  'yellow moong dal': 7,
#  'ginger finely': 1,
#  'dal sugar': 1,
#  'sprouted moong': 3,
#  'chow chow': 1,
#  'sesame oil oil': 2,
#  'red chilli': 21,
#  'black urad dal': 19,
#  'gulkand': 11,
#  'flour (maida) rolling': 1,
#  'baby spinach': 6,
#  'black rice': 11,
#  'button mushrooms (button crimini variety)': 2,
#  'parmesan cheese (reduced fat)': 2,
#  'mascarp cheese': 7,
#  'cheese (reduced fat fat free)': 2,
#  'mozzarella cheese (partskimmed)': 2,
#  'tomato pulp scooped out': 1,
#  'mutton kheema': 4,
#  'black gram soak cook till becomes soft': 1,
#  'spoon coconut': 1,
#  'sprig basil leaves': 45,
#  'mustard sauce': 18,
#  'apple cider vinegar': 15,
#  'black eyed beans (lobia) two': 1,
#  'dry red chillies gundu milagai)': 1,
#  'sunflower seeds': 15,
#  'melon seeds': 13,
#  'curry leaves pat dried': 2,
#  'del monte mint mayo': 10,
#  'lemon squeezed': 6,
#  'sev finer': 1,
#  'chiroti rava': 6,
#  'cajun spice mix': 1,
#  'garlic (or garlic paste)': 1,
#  'green moong dal (split)': 12,
#  'sweetened coconut flakes': 1,
#  'chocolate bar': 8,
#  'ginger juliennes': 5,
#  'nutralite classic parathas': 1,
#  'seer fish': 4,
#  'aachi fish masala': 1,
#  'kokum (malabar tamarind)': 26,
#  'wheat flour rolling': 1,
#  'arhar dal (split toor dal) ground': 1,
#  'green chillies can also reduce': 1,
#  'amaranth leaves': 2,
#  'dried shrimps': 1,
#  'fish sauce soya sauce': 1,
#  'papaya unripened': 1,
#  'palm sugar brown sugar': 2,
#  'sunflower oil butter': 6,
#  'tapioca root': 4,
#  'butter have used salted butter': 1,
#  'matcha powder (japanese green tea)': 1,
#  'butter greasing': 5,
#  'red baby radish': 3,
#  'flour ( flour)': 4,
#  'wheat bran': 9,
#  'tsp dry yeast': 1,
#  'cucumbers': 10,
#  'red onion': 28,
#  'black peppercorns cracked': 2,
#  'lemon juice large limes': 1,
#  'tahini': 17,
#  'sun dried tomato dipped olive oil': 1,
#  'pomegranate sauce recipe': 1,
#  'dry yeast water': 1,
#  'turnips': 6,
#  'mutton': 51,
#  'poppy seeds paste': 4,
#  'english cucumber': 14,
#  'tofu rectangular shapes': 1,
#  'fish fillet': 7,
#  'mixed sprouts bowls': 1,
#  'hung curd (greek yogurt) fatfree': 1,
#  'egg white': 12,
#  'muesli': 20,
#  'strawberries': 53,
#  'chia seeds': 34,
#  'digestive biscuit': 6,
#  'dark chocolate curls': 1,
#  'kala jeera': 11,
#  'sprig tulsi (holy basil)': 4,
#  'betel leaves (paan)': 4,
#  'ghee plus': 2,
#  'pepper salt ( black pepper)': 1,
#  'lasagna sheets the that needs no pre': 1,
#  'bottle gourd (lauki)': 50,
#  'multigrain flour besan': 1,
#  'cashew nuts water': 3,
#  'prawns shelled': 1,
#  'leek': 9,
#  'almond essence (badam essence)': 5,
#  'plums': 2,
#  'coconut oil other oil': 2,
#  'foxtail millet': 23,
#  'ghee bfor': 1,
#  'dates water': 1,
#  'multigrain digestive oat biscuits': 5,
#  'pie crust': 4,
#  'potatoes (aloo) firm': 1,
#  'cheese (like flavored herbed cheese)': 1,
#  'nutralite classic': 14,
#  'salmon fillet': 1,
#  'sambal oelek': 1,
#  'sweet potatoes th': 1,
#  'eggs egg separated': 1,
#  'nutralite garlic oregano': 15,
#  'apples': 26,
#  'wheat noodles': 6,
#  'stalks spring onion greens': 7,
#  'pearl onion': 1,
#  'jackfruit (kathal)': 13,
#  'gilka (spongesilk squash)': 2,
#  'groundnut powder': 10,
#  'sesame powder': 4,
#  'maharashtrian goda masala': 20,
#  'tsp cinnamon powder': 1,
#  'karela (bitter gourd pavakkai) th': 2,
#  'oil ghee': 4,
#  'neem leaves': 2,
#  'sunflower oil saffola': 3,
#  'egg noodles': 4,
#  'nendra pazham banana (ripe)': 3,
#  'sunflower oil tempering': 4,
#  'thyme leaves dried': 2,
#  'curry powder': 13,
#  'saltlemon juice': 1,
#  'wood': 1,
#  'oil curry leaves': 1,
#  'dates seedless': 5,
#  'ghee greasing the plate': 3,
#  'coconut milk coconut': 1,
#  'rye powder': 1,
#  'poppy seeds powder': 1,
#  'garlic bud': 1,
#  'banana leaves steamer put': 1,
#  'banana leaves cook on low flame': 1,
#  'oil grease': 1,
#  'sunflower oil drops greasing': 3,
#  'puff pastry sheet': 9,
#  'apple': 43,
#  'broccoli florets approximately': 2,
#  'mixed vegetables (french beans': 2,
#  'fish': 6,
#  'medu vada': 1,
#  'gram butter': 8,
#  'gram sugar': 2,
#  'urad dal flour': 7,
#  'sesame (white)': 2,
#  'spoon tomato sauce': 1,
#  'prawns marinate': 1,
#  'oil per the usage': 1,
#  'dal sugar powder': 2,
#  'pav buns': 11,
#  'herb butter toasting the buns': 1,
#  'lahsun ki chutney (red garlic chutney)': 6,
#  'ginger powder': 1,
#  'ghee sesame oil': 3,
#  'virgin olive oil the patties': 1,
#  'shrikhand': 1,
#  'mixed fruits assortment fruits like': 1,
#  'potato masala': 3,
#  'garlic chutney': 1,
#  'potato': 10,
#  'green peas (matar) pod': 1,
#  'paneer ness': 2,
#  'ghee butter greasing': 1,
#  'gram chenna': 1,
#  'green bell pepper (capsicum) colour': 1,
#  'sunflower oil greasing the': 1,
#  'badam (almond) an hour': 1,
#  'orange pulp': 2,
#  'badam (almond) a': 2,
#  'mixed fruits (used figs': 1,
#  'green chawli beans (yard beanskaramanibarbati)': 4,
#  'basmati rice grain rice': 1,
#  'mixed vegetables (potato': 2,
#  'anardana powder (pomegranate seed powder) seeds': 1,
#  'ghee the malpua': 1,
#  'avocado': 27,
#  'virgin olive oil butter': 6,
#  'sprigs mint leaves (pudina)': 1,
#  'sprigs parsley leaves': 1,
#  'spinach basil sauce': 1,
#  'mixed herbs (dried)': 62,
#  'sunflower oil salt': 1,
#  'indian borage (doddapatre)': 2,
#  'tamarind (sm lemon size)': 1,
#  'mixed vegetables': 7,
#  'tomato ripe': 6,
#  'chicken curry': 9,
#  'tamarind.': 1,
#  'kashmiri dry red chilli': 8,
#  'lotus stem (nadru kamal kakdi)': 1,
#  'mint powder (pudina)': 3,
#  'chicken stock chicken stock cube water': 1,
#  'sherry white wine': 1,
#  'corn flour dissolved': 2,
#  'chicken breasts skinless bless': 1,
#  'bok choy heads': 1,
#  'rice water': 3,
#  'baby potatoes quatered': 1,
#  'dhansak masala': 5,
#  'carrot (gajjar) diagony': 5,
#  'soybeans (whole soya dal)': 8,
#  'green chickpeas frozen': 1,
#  'rice min': 2,
#  'double beans': 1,
#  'mango (raw) the skin': 1,
#  'singhade (water chestnut)': 5,
#  'rice ground': 2,
#  'virgin olive oil brushing': 1,
#  'confectirs sugar': 8,
#  'basmati rice mins': 1,
#  'egg only': 1,
#  'sprig basil leaves ground paste': 1,
#  'knol khol (ganth gobikadam)': 3,
#  'sunflower oil ghee': 25,
#  'phool makhana (lotus seeds)': 16,
#  'red chilli sauce (or birds eye chilli sauce)': 1,
#  'sunflower oil the pickle oil flavour': 1,
#  'clove cloves (laung)': 2,
#  'potato (aloo) salt water': 1,
#  'rajgira flour (amaranth flour)': 10,
#  'black peppercorns ground': 27,
#  'britannia cheese four pepper tango': 5,
#  'cheese over the bread': 1,
#  'suran boil': 1,
#  'banana boil': 1,
#  'amchur powder': 3,
#  'oats coat': 1,
#  'black chilli powder': 1,
#  'cocoa powder mixed tbsp. water': 1,
#  'strawberry compote': 4,
#  'butterscotch chips almonds': 1,
#  'beer': 2,
#  'watermelon': 15,
#  'black grapes': 5,
#  'tikka masala': 1,
#  'kashmiri dry red chillies': 16,
#  'condensed milk sweetened': 6,
#  'coconut strands': 1,
#  'napa cabbage': 1,
#  'carrot (gajjar) stripes': 1,
#  'arabic now': 1,
#  'tamarind malabar': 2,
#  'coconut scrape': 1,
#  'dry red chillies break': 2,
#  'mutton (used shanks)': 1,
#  'saffron strands milk': 9,
#  'ginger julienne': 5,
#  'shiitake mushrooms (or oyster mushrooms)': 1,
#  'oyster sauce': 2,
#  'bananas nendra variety': 1,
#  'dark chocolate chips': 8,
#  'eggs egg': 2,
#  'kabuli channa': 1,
#  'green capsicum': 2,
#  'kasuri methi': 8,
#  'rice cook': 2,
#  'ghee coriander': 1,
#  'dates ( dates': 1,
#  'cocoa powder (you can semi sweet cocoa also)': 1,
#  'gwar pods': 3,
#  'radishes': 3,
#  'cinnamon stick': 18,
#  'cumin (jeera) seeds': 22,
#  'coriander (dhania) powder': 23,
#  'green seedless grapes': 9,
#  'peanuts (moongphali) mortar pestle': 1,
#  'gram flour (sattu ka atta)': 6,
#  'pickle red chilli pickle': 1,
#  'sprig dill leaves': 9,
#  'yellow moong dal (split) mins': 1,
#  'bhindi (lady fingerokra) stripes': 1,
#  'black eyed beans (lobia) least': 1,
#  'cashews soak water': 1,
#  ...}

# %%
print(list(count.keys()))
# Out:
# ['karela (bitter gourd pavakkai)', 'salt', 'onion', 'gram flour (besan)', 'turmeric powder (haldi)', 'red chilli powder', 'cumin seeds (jeera)', 'coriander powder (dhania)', 'amchur (dry mango powder)', 'sunflower oil', 'rice', 'tomato', 'bc belle bhat powder', 'chickpea lentils', 'cumin seeds', 'white urad dal', 'mustard', 'green chilli', 'dry red chilli', 'cashew peanuts', 'oilasafoetida', 'rice vermicelli noodles (thin)', 'carrots (gajjar)', 'green peas (matar)', 'green chillies', 'asafoetida (hing)', 'mustard seeds', 'white urad dal (split)', 'ghee', 'sprig curry leaves', 'lemon juice', 'chicken', 'ginger', 'cloves garlic', 'garam masala powder', 'sesame (gingelly) oil', 'methi seeds (fenugreek seeds)', 'coriander (dhania) seeds', 'dry red chillies', 'fennel seeds (saunf)', 'sorrel leaves (gongura)', 'chana dal', 'red chillies', 'coriander seeds', 'asafoetida', 'oil', 'sprig curry', 'yellow moong dal (split)', 'mint leaves (pudina)', 'coriander (dhania) leaves', 'water', 'cashew nuts', 'black peppercorns', 'vellai poosanikai (ash gourdwhite pumpkin)', 'coconut', 'tamarind water', 'sesame seeds (til seeds)', 'jaggery', 'tortillas', 'black beans', 'spinach leaves (palak)', 'sprig coriander (dhania) leaves', 'rice brown rice', 'spring onion greens', 'cheddar cheese', 'hung curd (greek yogurt)', 'idli', 'green bell pepper (capsicum)', 'tomato ketchup', 'cabbage leaves', 'tamarind', 'turmeric powder', 'spoon oil', 'rye', 'dry beans (such cannellini soya beans)', 'virgin olive oil', 'clove garlic', 'hy', 'cumin powder (jeera)', 'dried oregano', 'red chilli powder cayenne pepper', 'pepper ( pepper)', 'burger buns', 'jalapenos', 'cheese', 'potatoes (aloo) pressure', 'egg', 'wheat bread crumbs', 'soy granules', 'red chilli flakes', 'tabasco original sauce', 'arhar dal (split toor dal)', 'aar maach (fish) rohu katla fish (cut steaks)', 'bay leaves (tej patta)', 'ginger paste', 'mustard oil', 'sugar', 'potatoes (aloo) skin', 'milk', 'black urad dal (split)', 'tamarind paste', 'eggs', 'cinnamon stick (dalchini)', 'bay leaf (tej patta)', 'cloves (laung)', 'curd', 'gourd', 'cucumber grind', 'green', 'green coriander', 'cumin powder', 'potatoes (aloo)', 'garlic powder', 'onion powder', 'flour (maida)', 'rice flour', 'sunflower oil the r tots', 'bay leaf break', 'carrot', 'green beans', 'potatoes', 'cloves', 'cinnamon', 'fennel', 'pepper', 'green peas', 'mint leaves', 'amla', 'bud garlic', 'mint', 'coriander', 'urad dal', 'wheat flour', 'cucumber', 'ghee on thalipeeth', 'submarine bread (subway bread) (flat breads foot s)', 'green moong sprouts', 'beetroot', 'stalks spring onion (bulb greens)', 'drumstick', 'coconut oil', 'mango pulp (puree)', 'saffron strands', 'badam (almond)', 'milk luke cold milk', 'ice cubes', 'idli dosa mixture', 'rice rava', 'cardamom powder', 'cardamom (elaichi) podsseeds', 'cloves cloves (laung)', 'mace (javitri)', 'black cardamom (badi elaichi)', 'kasuri methi (dried fenugreek leaves)', 'kashmiri red chilli powder', 'samosas mini', 'baguette', 'butter', 'garlic', 'red bell pepper (capsicum) (', 'black pepper powder', 'italian', 'tomato pasta sauce', 'ajwain (carom seeds)', 'chana dal (bengal gram dal)', 'sweet chutney (date tamarind)', 'green chutney (coriander mint)', 'pomegranate fruit kernels', 'sev', 'green beans (french beans)', 'soy sauce', 'thai sweet chilli sauce', 'rice wine vinegar', 'peanuts (moongphali)', 'baking powder', 'water make the dough', 'sesame seeds (til seeds) white', 'vanilla', 'sundkai', 'fenugreek', 'arhar dal', 'sambar powder', 'coriander powder', 'curry leaves', 'cabbage (patta gobi muttaikose)', 'spinach', 'green chilli sauce', 'cinnamon powder (dalchini)', 'dark chocolate', 'cocoa powder', 'salted butter', 'baking soda', 'britannia', 'caster sugar', 'raspberries', 'ada', 'milk full', 'cardamom powder (elaichi)', 'tindora (dondakaya kovakkai)', 'split methi seeds (methi kuria)', 'split mustard seeds (rai kuria)', 'chicken legs', 'kalonji (onion nigella seeds)', 'jackfruit seeds (kath ...

# %%
dict(sorted(count.items(), key=lambda item: item[1] ,reverse=True))
# Out:
# {'salt': 5426,
#  'onion': 2345,
#  'sunflower oil': 2273,
#  'turmeric powder (haldi)': 1917,
#  'red chilli powder': 1696,
#  'cloves garlic': 1561,
#  'ginger': 1423,
#  'tomato': 1347,
#  'cumin seeds (jeera)': 1310,
#  'green chillies': 1299,
#  'water': 1140,
#  'mustard seeds': 1077,
#  'sugar': 1067,
#  'ghee': 865,
#  'asafoetida (hing)': 855,
#  'coriander (dhania) leaves': 819,
#  'garam masala powder': 809,
#  'black pepper powder': 801,
#  'lemon juice': 791,
#  'sprig curry leaves': 788,
#  'coconut': 778,
#  'coriander powder (dhania)': 733,
#  'virgin olive oil': 715,
#  'dry red chillies': 656,
#  'cumin powder (jeera)': 654,
#  'green chilli': 649,
#  'butter': 644,
#  'milk': 614,
#  'curd': 569,
#  'cinnamon stick (dalchini)': 509,
#  'flour (maida)': 508,
#  'wheat flour': 462,
#  'black peppercorns': 451,
#  'sprig coriander (dhania) leaves': 449,
#  'cloves (laung)': 428,
#  'cardamom (elaichi) podsseeds': 426,
#  'jaggery': 411,
#  'curry leaves': 373,
#  'white urad dal (split)': 367,
#  'fennel seeds (saunf)': 323,
#  'carrot (gajjar)': 321,
#  'gram flour (besan)': 320,
#  'bay leaf (tej patta)': 317,
#  'eggs': 314,
#  'ginger garlic paste': 314,
#  'cardamom powder (elaichi)': 307,
#  'coriander (dhania) seeds': 305,
#  'cashew nuts': 305,
#  'potatoes (aloo)': 290,
#  'dry red chilli': 289,
#  'green bell pepper (capsicum)': 289,
#  'vanilla': 289,
#  'hy': 286,
#  'chana dal (bengal gram dal)': 282,
#  'red chilli flakes': 280,
#  'methi seeds (fenugreek seeds)': 279,
#  'mint leaves (pudina)': 278,
#  'baking powder': 271,
#  'garlic': 267,
#  'rice': 242,
#  'mustard oil': 242,
#  'ajwain (carom seeds)': 233,
#  'pepper': 229,
#  'green peas (matar)': 225,
#  'dried oregano': 223,
#  'paneer': 219,
#  'peanuts (moongphali)': 215,
#  'chaat masala powder': 214,
#  'soy sauce': 208,
#  'oil': 207,
#  'badam (almond)': 206,
#  'red bell pepper (capsicum)': 206,
#  'amchur (dry mango powder)': 204,
#  'turmeric powder': 204,
#  'sesame seeds (til seeds)': 203,
#  'coconut milk': 197,
#  'corn flour': 196,
#  'cinnamon powder (dalchini)': 188,
#  'rice flour': 185,
#  'carrots (gajjar)': 177,
#  'button mushrooms': 174,
#  'coconut oil': 168,
#  'kashmiri red chilli powder': 168,
#  'saffron strands': 167,
#  'egg': 166,
#  'potato (aloo)': 166,
#  'sesame (gingelly) oil': 161,
#  'caster sugar': 161,
#  'arhar dal (split toor dal)': 160,
#  'baking soda': 160,
#  'raisins': 159,
#  'hung curd (greek yogurt)': 146,
#  'green beans (french beans)': 145,
#  'sweet corn': 145,
#  'coriander (dhania)': 141,
#  'sooji (semolina rava)': 136,
#  'pistachios': 136,
#  'lemon': 134,
#  'brown sugar (demerara sugar)': 133,
#  'kasuri methi (dried fenugreek leaves)': 132,
#  'tamarind water': 129,
#  'poppy seeds': 128,
#  'cheese': 126,
#  'cumin seeds': 125,
#  'yellow moong dal (split)': 121,
#  'mozzarella cheese': 120,
#  'tamarind paste': 115,
#  'red chilli sauce': 115,
#  'spinach leaves (palak)': 114,
#  'cucumber': 114,
#  'instant oats (oatmeal)': 113,
#  'spinach': 110,
#  'cabbage (patta gobi muttaikose)': 109,
#  'bay leaves (tej patta)': 108,
#  'coriander powder': 106,
#  'basmati rice': 103,
#  'brinjal (baingan eggplant)': 103,
#  'black cardamom (badi elaichi)': 102,
#  'basil leaves': 102,
#  'wheat bread crumbs': 101,
#  'wheat brown bread': 100,
#  'chicken': 99,
#  'walnuts': 97,
#  'tamarind': 96,
#  'cocoa powder': 95,
#  'dry yeast': 95,
#  'spring onion greens': 94,
#  'methi leaves (fenugreek leaves)': 94,
#  'vinegar': 94,
#  'chicken breasts': 94,
#  'sambar powder': 93,
#  'paprika powder': 91,
#  'star anise': 89,
#  'parmesan cheese': 88,
#  'mustard': 84,
#  'broccoli': 84,
#  'pearl onion (sambar onion)': 83,
#  'parsley leaves': 81,
#  'bananas': 81,
#  'cauliflower (gobi)': 80,
#  'white urad dal': 79,
#  'yellow bell pepper (capsicum)': 78,
#  'dry ginger powder': 78,
#  'ginger paste': 77,
#  'kabuli chana (white chickpeas)': 77,
#  'asafoetida': 75,
#  'nutmeg powder': 75,
#  'beetroot': 72,
#  'spring onion (bulb greens)': 71,
#  'black salt': 71,
#  'vegetable stock': 69,
#  'tomato ketchup': 68,
#  'kalonji (onion nigella seeds)': 68,
#  'sprig mint leaves (pudina)': 66,
#  'green zucchini': 65,
#  'ku (parangikai pumpkin)': 65,
#  'cheddar cheese': 64,
#  'tofu': 62,
#  'mango (raw)': 62,
#  'mixed herbs (dried)': 62,
#  'dates': 61,
#  'heavy whipping': 60,
#  'garlic paste': 59,
#  'mango (ripe)': 59,
#  'clove garlic': 58,
#  '': 58,
#  'coriander (dhania) leaves sprigs': 57,
#  'dried thyme leaves': 56,
#  'masoor dal': 56,
#  'rajma (large kidney beans)': 55,
#  'condensed milk': 55,
#  'orange': 53,
#  'cherry tomato': 53,
#  'strawberries': 53,
#  'black pepper corns': 52,
#  'lemon juiced': 52,
#  'black urad dal (split)': 51,
#  'black olives': 51,
#  'green moong dal': 51,
#  'mutton': 51,
#  'green chutney (coriander mint)': 50,
#  'vivatta maida': 50,
#  'bottle gourd (lauki)': 50,
#  'cumin powder': 49,
#  'green moong sprouts': 49,
#  'kala chana (brown chickpeas)': 49,
#  'dry coconut (kopra)': 49,
#  'icing sugar': 49,
#  'britannia': 48,
#  'bhindi (lady fingerokra)': 47,
#  'poha (flattened rice)': 46,
#  'banana': 46,
#  'ragi flour (finger millet nagli)': 46,
#  'pineapple': 46,
#  'dark chocolate': 45,
#  'sprig basil leaves': 45,
#  'mooli mullangi (radish)': 44,
#  'ghee oil': 44,
#  'orange juice': 44,
#  'rosemary': 43,
#  'apple': 43,
#  'jalapenos': 42,
#  'green coriander': 42,
#  'enos fruit salt': 42,
#  'panch phoran masala': 42,
#  'rose water': 42,
#  'feta cheese': 41,
#  'ice cubes': 40,
#  'mace (javitri)': 40,
#  'sweet chutney (date tamarind)': 40,
#  'baby potatoes': 40,
#  'italian': 39,
#  'dill leaves': 39,
#  'fennel powder': 39,
#  'anardana powder (pomegranate seed powder)': 38,
#  'water knead': 38,
#  'chocolate chips': 38,
#  'drumstick': 37,
#  'baby corn': 37,
#  'iceberg lettuce': 37,
#  'khoya (mawa)': 37,
#  'buttermilk': 37,
#  'garlic powder': 36,
#  'sprig parsley leaves': 36,
#  'cauliflower (gobi) florets': 36,
#  'tamarind lemon': 36,
#  'red chillies': 35,
#  'rye': 35,
#  'pomegranate fruit kernels': 35,
#  'gram dal (pottukadalai)': 35,
#  'tabasco original sauce': 34,
#  'cinnamon': 34,
#  'bless chicken': 34,
#  'chia seeds': 34,
#  'green chilli paste': 33,
#  'sweet potatoes': 33,
#  'coriander': 32,
#  'quinoa': 32,
#  'karela (bitter gourd pavakkai)': 31,
#  'milk powder': 31,
#  'elephant yam (suransenairatalu)': 31,
#  'bajra flour ( pearl millet)': 31,
#  'black eyed beans (lobia)': 31,
#  'idli rice': 31,
#  'prawns': 30,
#  'cashews': 30,
#  'mixed nuts': 30,
#  'almond meal (badam powder)': 30,
#  'celery': 30,
#  'jowar flour (sorghum)': 30,
#  'peanut butter': 30,
#  'flax seed powder (flax meal)': 29,
#  'sour': 29,
#  'tortillas': 28,
#  'soda': 28,
#  'red onion': 28,
#  'nutmeg': 28,
#  'bay leaf': 27,
#  'sriracha sauce': 27,
#  'cardamom': 27,
#  'avocado': 27,
#  'black peppercorns ground': 27,
#  'pizza pasta sauce': 27,
#  'brown rice': 26,
#  'broccoli florets': 26,
#  'classic mayonnaise (with egg)': 26,
#  'kokum (malabar tamarind)': 26,
#  'apples': 26,
#  'coriander seeds': 25,
#  'sev': 25,
#  'green chilli sauce': 25,
#  'wheat (dalia godumai rava)': 25,
#  'white pepper powder': 25,
#  'chilli vinegar': 25,
#  'almonds (badam)': 25,
#  'fenugreek seeds': 25,
#  'sunflower oil ghee': 25,
#  'tomato pasta sauce': 24,
#  'makki ka atta (yellow corn meal flour)': 24,
#  'sweet spicy red chilli sauce (tomato chilli sauce)': 24,
#  'dark soy sauce': 24,
#  'asafetida': 24,
#  'gingelly oil': 24,
#  'onion paste': 24,
#  'instant coffee powder': 24,
#  'byadagi dried chillies': 24,
#  'cabbage': 23,
#  'gram flour': 23,
#  'idli dosa batter': 23,
#  'foxtail millet': 23,
#  'coriander (dhania) powder': 23,
#  'sweet potato': 23,
#  'dijon mustard': 22,
#  'cumin': 22,
#  'carrots': 22,
#  'cumin (jeera) seeds': 22,
#  'chana dal': 21,
#  'potatoes': 21,
#  'pav bhaji masala': 21,
#  'garlic cloves': 21,
#  'red yellow green bell peppers (capsicum)': 21,
#  'sabudana (tapioca pearls)': 21,
#  'red chilli': 21,
#  'cranberries': 21,
#  'horse gram dal (kollu kulith)': 21,
#  'green peas': 20,
#  'white vinegar': 20,
#  'red wine vinaigrette': 20,
#  'capsicum (green)': 20,
#  'coriander (dhania) leavesfor': 20,
#  'rolled oats instant oats': 20,
#  'papaya': 20,
#  'muesli': 20,
#  'maharashtrian goda masala': 20,
#  'sprig green coriander': 19,
#  'colocasia root (arbi)': 19,
#  'spaghetti pasta': 19,
#  'thyme leaves': 19,
#  'black urad dal': 19,
#  'oats flour': 19,
#  'green bell peppers': 19,
#  'figaro pure olive oil': 19,
#  'soy (nuggets)': 18,
#  'red yellow green bell pepper (capsicum)': 18,
#  'mustard sauce': 18,
#  'cinnamon stick': 18,
#  'ridge gourd (turai peerkangai)': 18,
#  'penne pasta': 18,
#  'mango pulp (puree)': 17,
#  'rasam powder': 17,
#  'sprig spring onion (bulb greens)': 17,
#  'rice vinegar': 17,
#  'drumstick leaves (moringamurungai keerai)': 17,
#  'tahini': 17,
#  'lemon juice from lemon': 17,
#  'coriander leaves': 16,
#  'yogurt': 16,
#  'phool makhana (lotus seeds)': 16,
#  'kashmiri dry red chillies': 16,
#  'black pepper powder ground': 16,
#  'kiwi': 16,
#  'britannia cheese block': 16,
#  'black sesame seeds': 16,
#  'sprig thyme leaves': 16,
#  'balsamic vinegar': 16,
#  'peanuts': 16,
#  'green beans': 15,
#  'stalks spring onion (bulb greens)': 15,
#  'hakka noodles': 15,
#  'dried figs': 15,
#  'tomato salsa': 15,
#  'apple cider vinegar': 15,
#  'sunflower seeds': 15,
#  'nutralite garlic oregano': 15,
#  'watermelon': 15,
#  'dried basil leaves': 15,
#  'palm sugar': 15,
#  'carrot': 14,
#  'salted butter': 14,
#  'bay leaves': 14,
#  'english cucumber': 14,
#  'nutralite classic': 14,
#  'beetroots': 14,
#  'cloves cloves (laung)': 13,
#  'sesame oil': 13,
#  'sprig coriander': 13,
#  'lentil sugar': 13,
#  'fish sauce': 13,
#  'flax seeds': 13,
#  'amla (nellikai gooseberry)': 13,
#  'butter cold': 13,
#  'melon seeds': 13,
#  'jackfruit (kathal)': 13,
#  'curry powder': 13,
#  'cashew nuts ground paste': 13,
#  'vegetable stock water': 13,
#  'boondi': 13,
#  'puffed rice': 13,
#  'barnyard millet': 13,
#  'sprig spring onion greens': 13,
#  'rice wine vinegar': 12,
#  'pumpkin seeds': 12,
#  'gawar phali (kothavarangai cluster beans)': 12,
#  'dried rose': 12,
#  'light soy sauce': 12,
#  'green moong dal (split)': 12,
#  'egg white': 12,
#  'st flower': 12,
#  'tamarind marble': 12,
#  'semiya (vermicelli)': 12,
#  'buckwheat flour (kuttu ka atta)': 12,
#  'purple cabbage': 12,
#  'nutella': 12,
#  'thai red curry paste': 12,
#  'maple syrup hy': 12,
#  'ricotta cheese': 12,
#  'avarekalu lilva beans': 12,
#  'onion powder': 11,
#  'chicken stock': 11,
#  'green amaranth leaves': 11,
#  'salt per': 11,
#  'apricots': 11,
#  'figs': 11,
#  'lettuce leaves': 11,
#  'lemon juice lemon': 11,
#  'parsley': 11,
#  'gulkand': 11,
#  'black rice': 11,
#  'kala jeera': 11,
#  'pav buns': 11,
#  'yellow zucchini': 11,
#  'tandoori masala': 11,
#  'bean sprouts': 11,
#  'rose': 11,
#  'custard powder': 11,
#  'thai red chilli (birds eye chilli)': 11,
#  'macaroni pasta': 11,
#  'sun dried tomato': 11,
#  'curry leaves sprigs': 11,
#  'vellai poosanikai (ash gourdwhite pumpkin)': 10,
#  'burger buns': 10,
#  'potatoes (aloo) skin': 10,
#  'bud garlic': 10,
#  'baguette': 10,
#  'arhar dal': 10,
#  'milk full': 10,
#  'eggplant': 10,
#  'mango': 10,
#  'nutralite cheesy garlic mayo': 10,
#  'chinese spice powder': 10,
#  'del monte cheesy garlic mayo': 10,
#  'methi powder (fenugreek powder)': 10,
#  'salt salt': 10,
#  'sprigs coriander (dhania) leaves': 10,
#  'tender coconut water': 10,
#  'paneer cubes': 10,
#  'del monte mint mayo': 10,
#  'cucumbers': 10,
#  'groundnut powder': 10,
#  'potato': 10,
#  'rajgira flour (amaranth flour)': 10,
#  'badam (almond) skin': 10,
#  'aerated water (soda water)': 10,
#  'prunes': 10,
#  'spice powder': 10,
#  'ghee butter': 10,
#  'ragi seeds': 10,
#  'blueberries': 10,
#  'prawns deveined': 10,
#  'schezwan sauce': 10,
#  'rolled oats': 10,
#  'red cabbage': 10,
#  'rice vermicelli noodles (thin)': 9,
#  'fennel': 9,
#  'tindora (dondakaya kovakkai)': 9,
#  'bok choy': 9,
#  'black pepper': 9,
#  'pointed gourd (parval)': 9,
#  'stalks lemongrass': 9,
#  'del monte corn kernels': 9,
#  'bajra (seeds)': 9,
#  'jowar seeds': 9,
#  'ice': 9,
#  'barley (seeds)': 9,
#  'wheat bran': 9,
#  'leek': 9,
#  'puff pastry sheet': 9,
#  'chicken curry': 9,
#  'saffron strands milk': 9,
#  'green seedless grapes': 9,
#  'sprig dill leaves': 9,
#  'pepper powder': 9,
#  'green chillies()': 9,
#  'olive oil': 9,
#  'dosa rice': 9,
#  'white chocolate': 9,
#  'mace powder': 9,
#  'badi (wadi)': 9,
#  'del monte black olives': 9,
#  'del monte tandoori mayo': 9,
#  'cloves (laung) garlic': 9,
#  'mangalorean cucumber': 9,
#  'almond milk (badam milk': 9,
#  'green chillies paste': 9,
#  'double': 9,
#  'black beans': 8,
#  'soy granules': 8,
#  'cardamom powder': 8,
#  'jackfruit seeds (kathal)': 8,
#  'tomato paste': 8,
#  'brown cardamom (badi elaichi)': 8,
#  'taco shells': 8,
#  'tomato pulp': 8,
#  'mango powder': 8,
#  'sprig coriander (dhania) leavesfor': 8,
#  'edible silver foilleaf (chandi ka vark)': 8,
#  'cloves garlic pound': 8,
#  'pink masoor dal (split)': 8,
#  'chocolate bar': 8,
#  'gram butter': 8,
#  'kashmiri dry red chilli': 8,
#  'soybeans (whole soya dal)': 8,
#  'confectirs sugar': 8,
#  'dark chocolate chips': 8,
#  'kasuri methi': 8,
#  'lemongrass': 8,
#  'tutti frutti': 8,
#  'red matta rice': 8,
#  'shrimps deveined': 8,
#  'cranberries dried': 8,
#  'water knead the dough': 8,
#  'sweet potato skin': 8,
#  'tomato basil pasta sauce': 8,
#  'chicken breasts bless': 8,
#  'stalks celery': 8,
#  'mutton on the': 8,
#  'date syrup': 8,
#  'sprig rosemary': 8,
#  'cherries': 8,
#  'avarekai (broad beans)': 8,
#  'gelatin': 8,
#  'mint': 7,
#  'sesame seeds (til seeds) white': 7,
#  'chicken legs': 7,
#  'sprigs coriander': 7,
#  'kasundi mustard sauce': 7,
#  'capsicum (red)': 7,
#  'thai basil leaves': 7,
#  'mixed dry fruits': 7,
#  'salt oil': 7,
#  're beans': 7,
#  'vanilla ice': 7,
#  'chocolate sauce': 7,
#  'mint leaves (pudina) sprigs': 7,
#  'lotus stem': 7,
#  'pecans': 7,
#  'pomegranate': 7,
#  'red chilli paste': 7,
#  'yellow moong dal': 7,
#  'mascarp cheese': 7,
#  'fish fillet': 7,
#  'stalks spring onion greens': 7,
#  'urad dal flour': 7,
#  'mixed vegetables': 7,
#  'chenna': 7,
#  'achari mayo': 7,
#  'worcestershire sauce': 7,
#  'eggless mayonnaise': 7,
#  'britannia cheezza': 7,
#  'green olives': 7,
#  'sunflower oil oil': 7,
#  'tofu firm': 7,
#  'tamarind gooseberry': 7,
#  'cashew nuts paste': 7,
#  'chironji': 7,
#  'shrimps': 7,
#  'del monte spaghetti pasta': 7,
#  'idli dosa podi (milagai powder)': 7,
#  'arborio rice': 7,
#  'maple syrup': 7,
#  'yellow mustard seeds': 7,
#  'banana leaf': 7,
#  'coconut sugar': 7,
#  ')': 7,
#  'chicken bless': 7,
#  'saffron strands generous': 7,
#  'achari masala': 7,
#  'palm jaggery': 7,
#  'guava': 7,
#  'black salt salt': 7,
#  'peppermint': 7,
#  'pumpkin': 7,
#  'milk full fat': 7,
#  'wheat flour tortilla': 7,
#  'stalk celery': 7,
#  'rice noodles (flat)': 7,
#  'potato (aloo) skin': 7,
#  'mint leaves': 6,
#  'rice rava': 6,
#  'green onion': 6,
#  'kasoori methi': 6,
#  'tulsi (holy basil)': 6,
#  'peanuts roast': 6,
#  'tzatziki': 6,
#  'chana masala powder': 6,
#  'spinach leaves (palak) bunch': 6,
#  'mustard greens': 6,
#  'thandai masala': 6,
#  'pizza': 6,
#  'pani puris': 6,
#  'spirulina': 6,
#  'ginger ground paste': 6,
#  'baby spinach': 6,
#  'lemon squeezed': 6,
#  'chiroti rava': 6,
#  'sunflower oil butter': 6,
#  'turnips': 6,
#  'digestive biscuit': 6,
#  'wheat noodles': 6,
#  'fish': 6,
#  'lahsun ki chutney (red garlic chutney)': 6,
#  'virgin olive oil butter': 6,
#  'tomato ripe': 6,
#  'condensed milk sweetened': 6,
#  'gram flour (sattu ka atta)': 6,
#  'wheat flour maida': 6,
#  'sunflower oil brush': 6,
#  'jackfruit ripe (kathal)': 6,
#  'bacon strips': 6,
#  'cocoa powder unsweetened': 6,
#  'peanut oil': 6,
#  'conchiglie pasta': 6,
#  'chow chow (chayote squash)': 6,
#  'harissa paste': 6,
#  'curd sour': 6,
#  'mixed fruits': 6,
#  'pomfret fish': 6,
#  'couscous': 6,
#  'dry mix herbs': 6,
#  'red wine': 6,
#  'chaat masala powder sprinkling': 6,
#  'clove powder (laung)': 6,
#  'sichuan peppercorns': 6,
#  'hoisin sauce': 6,
#  'sugar jaggery': 6,
#  'basil pesto': 6,
#  'guacamole': 6,
#  'sunflower oil pan': 6,
#  'mooli ke patte (radish greens)': 6,
#  'saffron strands strands': 6,
#  'pineapple juice': 6,
#  'cloves garlic ground paste': 6,
#  'chicken thighs': 6,
#  'decorative sugar (cake candy s)': 6,
#  'wheat berries wheat': 6,
#  'potatoes boil': 6,
#  'cayenne pepper': 6,
#  'dried green peas (vatana)': 6,
#  'cinnamon powder': 6,
#  'water the dough': 6,
#  'idli': 5,
#  'gourd': 5,
#  'fenugreek': 5,
#  'sprig mint': 5,
#  'suran': 5,
#  'biryani masala': 5,
#  'hummus': 5,
#  'oreo biscuits': 5,
#  'button mushrooms quatered': 5,
#  'potatoes (aloo) cubes': 5,
#  'pine nuts': 5,
#  'jaggery sugar': 5,
#  'ginger ground': 5,
#  'sprigs curry leaves': 5,
#  'sesame seeds (til seeds) dry': 5,
#  'green peas (matar) frozen': 5,
#  'peanuts (moongphali) ground': 5,
#  'kalonji seeds': 5,
#  'ghee the parathas': 5,
#  'ginger juliennes': 5,
#  'butter greasing': 5,
#  'almond essence (badam essence)': 5,
#  'multigrain digestive oat biscuits': 5,
#  'dates seedless': 5,
#  'dhansak masala': 5,
#  'carrot (gajjar) diagony': 5,
#  'singhade (water chestnut)': 5,
#  'britannia cheese four pepper tango': 5,
#  'black grapes': 5,
#  'ginger julienne': 5,
#  'rosemary dried': 5,
#  'govind bhog rice': 5,
#  'dry fruits': 5,
#  'fennel seeds': 5,
#  'kewra water': 5,
#  'corn kernels': 5,
#  'britannia cheese garlic': 5,
#  'guntur dried chillies': 5,
#  'canned cherries': 5,
#  'arugula leaves': 5,
#  'spirali pasta': 5,
#  'sunflower oil greasing': 5,
#  'capers': 5,
#  'instant oats (oatmeal) instant': 5,
#  'mutton bless': 5,
#  'basil leaves sprigs': 5,
#  'polenta': 5,
#  'goat cheese': 5,
#  'garlic butter': 5,
#  "za'atar": 5,
#  'kosher salt': 5,
#  'corn flour tortilla': 5,
#  'tinda (apple gourd)': 5,
#  'canola oil': 5,
#  'mini pita breads': 5,
#  'snake gourd (pudulangai)': 5,
#  'kalmatta olives': 5,
#  'kaffir lime leaves': 5,
#  'spinach bunch': 5,
#  'green chillies verticy': 5,
#  'wheat brown bread wheat': 5,
#  'carrot (gajjar) th': 5,
#  'asafoetida (hing) generous': 5,
#  'red radish': 5,
#  'chives': 5,
#  'green brinjal (green aubergine)': 5,
#  'rice paper rolls': 5,
#  'sweet corn kernels': 5,
#  'butter oil': 5,
#  'garlic pods': 5,
#  'peaches': 5,
#  'walnuts pine nuts': 5,
#  'chicken breasts cubes': 5,
#  'canned black beans': 5,
#  'gelatin unflavoured': 5,
#  'banana flower (vazhaipoo)': 5,
#  'barbeque sauce': 5,
#  'marie biscuit': 5,
#  'peanuts (moongphali) pound': 5,
#  'chicken bs': 5,
#  'hy maple syrup': 5,
#  'bay leaf break': 4,
#  'amla': 4,
#  'split mustard seeds (rai kuria)': 4,
#  'tea leaves': 4,
#  'oregano': 4,
#  'cane sugar': 4,
#  'rice (raw rice)': 4,
#  'spoon turmeric powder': 4,
#  'del monte sandwich': 4,
#  'onion red': 4,
#  'tamarind pulp': 4,
#  'chocolate ganache': 4,
#  'large cardamom': 4,
#  'star anis': 4,
#  'lemon juice drops': 4,
#  'coffee decoction': 4,
#  'enos fruit salt baking powder': 4,
#  'almonds': 4,
#  'yellow food colour': 4,
#  'ghee roasting': 4,
#  'mutton kheema': 4,
#  'seer fish': 4,
#  'tapioca root': 4,
#  'flour ( flour)': 4,
#  'poppy seeds paste': 4,
#  'sprig tulsi (holy basil)': 4,
#  'betel leaves (paan)': 4,
#  'pie crust': 4,
#  'sesame powder': 4,
#  'oil ghee': 4,
#  'egg noodles': 4,
#  'sunflower oil tempering': 4,
#  'green chawli beans (yard beanskaramanibarbati)': 4,
#  'strawberry compote': 4,
#  'moth dal (matki)': 4,
#  'dagad phool (pathar phoolblack st flower)': 4,
#  'sunflower oil grease': 4,
#  'fennel seeds (saunf) ground powder': 4,
#  'seeraga (jeeraga) samba rice': 4,
#  'green chickpeas': 4,
#  'herb butter': 4,
#  'rose essence': 4,
#  'del monte cheesy dip': 4,
#  'methi leaves (fenugreek leaves) bunch': 4,
#  'sunflower oil brushing': 4,
#  'amaranth seeds (rajgira)': 4,
#  'bathua leaves': 4,
#  'thai green curry paste': 4,
#  'sugar syrup': 4,
#  'toothpicks': 4,
#  'white broad beans': 4,
#  'britannia cheese classic': 4,
#  'spoon garam masala powder': 4,
#  'mixed nuts (almonds': 4,
#  'ghee ghee': 4,
#  'pears': 4,
#  'mint leaves (pudina) a': 4,
#  'turmeric': 4,
#  'green bell pepper (capsicum) squares': 4,
#  'fruits': 4,
#  'horse gram dal (kollu kulith) sprouted': 4,
#  'sprig ginger teriyaki sauce': 4,
#  'cloves (laung) cloves': 4,
#  'boiled egg': 4,
#  'red poha (flattened red rice)': 4,
#  'cocunut': 4,
#  'caramel sauce': 4,
#  'amul': 4,
#  'stalk coriander (dhania) leaves': 4,
#  'mustard powder': 4,
#  'butter pea': 4,
#  'ginger juice': 4,
#  'water vegetable stock': 4,
#  'plantain stem': 4,
#  'ku (parangikai pumpkin) skin': 4,
#  'semolina': 4,
#  'green bell pepper (capsicum) th': 4,
#  'britannia cheese asli pepper': 4,
#  'cumin powder (jeera) ground': 4,
#  'saffron strands strands milk': 4,
#  'singoda flour (water chestnut)': 4,
#  'green beans (french beans) diagony': 4,
#  'papaya paste': 4,
#  'mixed sprouts': 4,
#  'chayote': 4,
#  'water cold': 4,
#  'red amaranth leaves': 4,
#  'avocados': 4,
#  'bread cubes (croutons)': 4,
#  'cabbage (patta gobi muttaikose) leaves': 4,
#  'dry kashmiri chillies': 4,
#  'meat masala': 4,
#  'galangal ginger': 4,
#  'milk brushing': 4,
#  'chilli oil': 4,
#  'chicken wings': 4,
#  'chocolate shavings': 4,
#  'watermelon seeds': 4,
#  'chicken drumstick': 4,
#  'milk cold': 4,
#  'portobello mushrooms': 4,
#  'parsley leaves dried': 4,
#  'green grapes': 4,
#  'water needed': 4,
#  'water make batter': 4,
#  'veeba sweet chilli sauce': 4,
#  'stalk spring onion greens': 4,
#  'del monte farfe pasta': 4,
#  'poppy seeds ground paste': 4,
#  'tea bags': 4,
#  'walnuts pecans': 4,
#  'hy sugar': 4,
#  'dog bread': 4,
#  'papad': 4,
#  'soy (nuggets) water': 4,
#  'saltoil': 4,
#  'dry white wine': 4,
#  'britannia cheese mexican chilli': 4,
#  'sundakkai (turkey berries)': 4,
#  'bottle gourd (lauki) cubes': 4,
#  'tur dal': 4,
#  'sunflower oil tikkis': 4,
#  'assam tea leaves': 4,
#  'malwani masala': 4,
#  'pasta fusilli': 4,
#  'sweet potatoes skin': 4,
#  'thai yellow curry paste': 4,
#  'asafoetida (hing) asafoetida': 4,
#  'cloves (laung) ground': 4,
#  'onionlengthwise': 4,
#  'chickpea lentils': 3,
#  'red chilli powder cayenne pepper': 3,
#  'cloves': 3,
#  'urad dal': 3,
#  'split methi seeds (methi kuria)': 3,
#  'coal giving smoked flavour': 3,
#  'jasmine rice': 3,
#  'chakundar': 3,
#  'rice noodles': 3,
#  'black gram': 3,
#  'summer salad': 3,
#  'trumpet': 3,
#  'vanilla drops': 3,
#  'kidney beans': 3,
#  'ginger grated': 3,
#  'black peppers': 3,
#  'curry leaves break': 3,
#  'mace': 3,
#  'wheat flakes (cereal)': 3,
#  'aloo bhujia': 3,
#  'moth sprouts (matki)': 3,
#  'brinjal': 3,
#  'milk luke': 3,
#  'ghee greasing': 3,
#  'saffron': 3,
#  'corn flour mixed water': 3,
#  'red matta rice par': 3,
#  'sprig natural bourbon vanilla': 3,
#  'coconut milk toddy': 3,
#  'coconut grated': 3,
#  'green peas boil': 3,
#  'flour (maida) plus': 3,
#  'sprouted moong': 3,
#  'red baby radish': 3,
#  'cashew nuts water': 3,
#  'sunflower oil saffola': 3,
#  'nendra pazham banana (ripe)': 3,
#  'ghee greasing the plate': 3,
#  'sunflower oil drops greasing': 3,
#  'ghee sesame oil': 3,
#  'potato masala': 3,
#  'mint powder (pudina)': 3,
#  'rice water': 3,
#  'knol khol (ganth gobikadam)': 3,
#  'amchur powder': 3,
#  'gwar pods': 3,
#  'radishes': 3,
#  'garlic ground': 3,
#  'cayenne pepper ground': 3,
#  'rose water drops': 3,
#  'dry coconut': 3,
#  'sooji (semolina rava) semolina': 3,
#  'fennel bulb': 3,
#  'hung curd': 3,
#  'flour (maida) wheat flour': 3,
#  'badi hari mirch (large green chilli)': 3,
#  'coconut scrapped': 3,
#  'parmigiano reggiano cheese': 3,
#  'white onion': 3,
#  'hilsa fish': 3,
#  'corn meal': 3,
#  'mixed vegetables (beans': 3,
#  'vangi bath powder': 3,
#  'chipotle sauce': 3,
#  'bagel': 3,
#  'virgin olive oil drizzling': 3,
#  'green chilliesor': 3,
#  'khuskhus': 3,
#  'virgin olive oil ( virgin)': 3,
#  'colocasia root (arbi) skin': 3,
#  'curd buttermilk': 3,
#  'cumin powder (jeera) (roast ground)': 3,
#  'butter cooled': 3,
#  'sprigs basil leaves': 3,
#  'baked beans': 3,
#  'sprigs spring onion greens': 3,
#  'kaffir lime leaves lemon leaves': 3,
#  'wheat germ': 3,
#  'garlic ground paste': 3,
#  'pistachios ground': 3,
#  'eggs flax meal egg replacer': 3,
#  'sultanas': 3,
#  'green toor dal (pigeon pea)': 3,
#  'okra': 3,
#  'hazelnut': 3,
#  'red bell pepper (capsicum) stripes': 3,
#  'turmeric root': 3,
#  'brussel sprouts': 3,
#  'mutton bs': 3,
#  'water bind the dough': 3,
#  'kala chana (brown chickpeas) sprouted': 3,
#  'sesame (gingelly) oil vegetable oil': 3,
#  'cowpea': 3,
#  'edible camphor (pacha karpooram)': 3,
#  'cinnamon stick (dalchini) ground': 3,
#  'nutmeg ground': 3,
#  'colocasia leaves (arbi)': 3,
#  'britannia cheese cubes': 3,
#  'arrowroot flour': 3,
#  'green romaine lettuce': 3,
#  'red seedless grapes': 3,
#  'red grapes': 3,
#  'red chilli flakes black pepper powder': 3,
#  'glazed cherries': 3,
#  'lemongrass stalk': 3,
#  'sprig spinach': 3,
#  'corn flakes': 3,
#  'pomegranate juice': 3,
#  'marinara sauce': 3,
#  'coconut milk unsweetened': 3,
#  'hung curd (greek yogurt) till smooth': 3,
#  'cloves cardamom (elaichi) podsseeds': 3,
#  'water grinding': 3,
#  'rohu fish': 3,
#  'gram paneer': 3,
#  'green onion leaves': 3,
#  'tsp turmeric powder': 3,
#  'white wine vinegar': 3,
#  'charcoal': 3,
#  'green apple': 3,
#  'lemons': 3,
#  'wheat brown bread multigrain': 3,
#  'basa fish': 3,
#  'bless chicken breasts': 3,
#  'celery stalks': 3,
#  'paprika powder smoked': 3,
#  'turmeric root turmeric powder': 3,
#  'butter cubes': 3,
#  'butter frozen': 3,
#  'chicken breasts bless skinless': 3,
#  'chipotle peppers': 3,
#  'sage': 3,
#  'red chilli powder green chilli paste': 3,
#  'french loaf': 3,
#  'mint leaves (pudina) bunch': 3,
#  'veg hakka noodles': 3,
#  'soy milk': 3,
#  'bananas fully ripe': 3,
#  'nolen gur': 3,
#  'green brinjal': 3,
#  'cloves garlicor': 3,
#  'green amaranth': 3,
#  'yellow fenugreek seeds': 3,
#  'gond (natural gum)': 3,
#  'cumin seeds (jeera) ground': 3,
#  'soy': 3,
#  'instant oats (oatmeal) rolled': 3,
#  'sunflower oil roasting': 3,
#  'milk chocolate': 3,
#  ...}
